# %% [markdown]
# # DSMarket - Forecasting

# %% [markdown]
# ## Instalacion de paquetes

# %%
# !pip install statsmodels
# !pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from statsmodels) (2.3.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from statsmodels) (1.16.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from statsmodels) (2.3.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (3.0.4)
# Requirement already satisfied: numpy in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from xgboost) (2.3.2)
# Requirement already satisfied: scipy in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from xgboost) (1.16.1)

# %% [markdown]
# ## Importamos librerias necesarias

# %%
import pandas as pd
import os
import numpy as np
import statsmodels
import re
import pickle

from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OrdinalEncoder

import xgboost as xgb

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from typing import Callable, List, Dict, Union

# %% [markdown]
# ## 1. Cargamos fichero de datos

# %%
df = pd.read_parquet("df_forecasting.parquet", engine="pyarrow")
print(df.shape)
df.head(3)
# Out:
# (8354260, 12)
#                        id              item    category    department  \
# 0  ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 1  ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 2  ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
#
#        store store_code  region  yearweek  n_sales  revenue  avg_sell_price  \
# 0  South_End      BOS_1  Boston    201105        0      0.0         12.7414
# 1  South_End      BOS_1  Boston    201106        0      0.0         12.7414
# 2  South_End      BOS_1  Boston    201107        0      0.0         12.7414
#
#              event
# 0    Without event
# 1        SuperBowl
# 2  Valentine's Day

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8354260 entries, 0 to 8354259
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              object
#  1   item            object
#  2   category        object
#  3   department      object
#  4   store           object
#  5   store_code      object
#  6   region          object
#  7   yearweek        int64
#  8   n_sales         int64
#  9   revenue         float64
#  10  avg_sell_price  float64
#  11  event           object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 764.9+ MB

# %%
series = df["yearweek"].nunique()
print("Cantidad de series temporales: ", series)
# Out:
# Cantidad de series temporales:  274

# %%
first_week = df["yearweek"].min()
last_week = df["yearweek"].max()
print(f"Semana inicial es {first_week}\nSemana final es {last_week}")
# Out:
# Semana inicial es 201105
# Semana final es 201617

# %% [markdown]
# ## 3. Validacion de nulos

# %%
def contar_nulos(*dataframes):
    """
    Cuenta los valores nulos, la cantidad de registros por columna y el porcentaje
    de nulos para cada DataFrame proporcionado.
    """
    for i, df in enumerate(dataframes):
        print(f"\nAnálisis del DataFrame {i+1}:")
        null_counts = df.isnull().sum()
        total_counts = df.shape[0]
        null_percentage = (null_counts / total_counts) * 100

        null_info_df = pd.DataFrame({
            'Cantidad Registros': total_counts,
            'Cantidad Nulos': null_counts,
            '% Nulos': null_percentage
        })

        # Mostrar la información para cada columna
        print(null_info_df[null_info_df['Cantidad Nulos'] > 0])

# %%
contar_nulos(df)
# Out:
# Análisis del DataFrame 1:
# Empty DataFrame
# Columns: [Cantidad Registros, Cantidad Nulos, % Nulos]
# Index: []

# %% [markdown]
# ## 4. EDA

# %% [markdown]
# ### Creacion de fecha para cada semana-año

# %%
# Asegurar tipos
df["yearweek"] = df["yearweek"].astype(str)

# Universo de semanas ISO en el rango
weeks_all = sorted(df["yearweek"].unique())
weeks_df = pd.DataFrame(weeks_all, columns=["yearweek"])

# Mapear yearweek → fecha fin de semana (lunes-based ISO) tomamos el lunes de la semana:
def iso_yearweek_to_date(yw):
    year = int(yw[:4]); week = int(yw[4:])
    # ISO: lunes de esa semana
    return pd.to_datetime(f"{year}-W{str(week).zfill(2)}-1", format="%G-W%V-%u")

weeks_df["date"] = weeks_df["yearweek"].map(iso_yearweek_to_date)

# %%
weeks_df
# Out:
#     yearweek       date
# 0     201105 2011-01-31
# 1     201106 2011-02-07
# 2     201107 2011-02-14
# 3     201108 2011-02-21
# 4     201109 2011-02-28
# ..       ...        ...
# 269   201613 2016-03-28
# 270   201614 2016-04-04
# 271   201615 2016-04-11
# 272   201616 2016-04-18
# 273   201617 2016-04-25
#
# [274 rows x 2 columns]

# %%
df = df.merge(weeks_df, on='yearweek', how='left')
df.head(3)
# Out:
#                        id              item    category    department  \
# 0  ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 1  ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 2  ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
#
#        store store_code  region yearweek  n_sales  revenue  avg_sell_price  \
# 0  South_End      BOS_1  Boston   201105        0      0.0         12.7414
# 1  South_End      BOS_1  Boston   201106        0      0.0         12.7414
# 2  South_End      BOS_1  Boston   201107        0      0.0         12.7414
#
#              event       date
# 0    Without event 2011-01-31
# 1        SuperBowl 2011-02-07
# 2  Valentine's Day 2011-02-14

# %% [markdown]
# ### EDA total ventas

# %%
def plot_ts_acf_pacf(y, title):
    '''
    Plots the ts you pass and the acf and pacf.
    '''
    fig = plt.figure(figsize = (12, 10))
    ax1, ax2, ax3 = fig.subplots(3, 1)

    ax1.plot(y)
    plot_acf(x = y, ax = ax2, lags = 14)
    plot_pacf(x = y, ax = ax3, lags = 14)

    plt.suptitle(t = title, fontsize = 20)

# %%
y = df.set_index("date").resample("W")["n_sales"].sum()

# %%
plot_ts_acf_pacf(y = y, title = "Weekly Sales for all items in all shops");

# %% [markdown]
# ### EDA tiendas

# %%
(
    df.
    groupby(["store_code"])
    ["revenue"].sum()
    .sort_values(ascending = False)
    .plot(kind = "bar", figsize = (12, 4))
);

# %% [markdown]
# ### EDA departments

# %%
(
    df.
    groupby(["department"])
    ["revenue"].sum()
    .sort_values(ascending = False)
    .plot(kind = "bar", figsize = (12, 4))
);

# %% [markdown]
# ### EDA categories

# %%
(
    df.
    groupby(["category"])
    ["revenue"].sum()
    .sort_values(ascending = False)
    .plot(kind = "bar", figsize = (12, 4))
);

# %% [markdown]
# ## 5. Tratamiento variables categoricas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8354260 entries, 0 to 8354259
# Data columns (total 13 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              object
#  1   item            object
#  2   category        object
#  3   department      object
#  4   store           object
#  5   store_code      object
#  6   region          object
#  7   yearweek        object
#  8   n_sales         int64
#  9   revenue         float64
#  10  avg_sell_price  float64
#  11  event           object
#  12  date            datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(9)
# memory usage: 828.6+ MB

# %%
df_labels = df[["id", "item", "category", "department", "store", "store_code", "region"]].drop_duplicates().reset_index(drop=True)

# %% [markdown]
# Usamos ordinal encoder para asignar un id a cada categoria en variables categoricas

# %%
# columnas categóricas a codificar
cat_cols = ["item", "category", "department", "region", "store_code", "region"]

# inicializar encoder
enc = OrdinalEncoder(
    handle_unknown="use_encoded_value",  # no fallar si aparece categoría nueva en futuros datos
    unknown_value=-1,
    dtype=np.int64
)

# ajustamos y transformamos en el mismo df
df[cat_cols] = enc.fit_transform(df[cat_cols]) + 1

# entrenamos y codificamos la columna "event" de manera independiente para poder usar el encoder posteriormente
enc_event = OrdinalEncoder(
    handle_unknown="use_encoded_value",  # no fallar si aparece categoría nueva en futuros datos
    unknown_value=-1,
    dtype=np.int64
)

df[["event"]] = enc_event.fit_transform(df[["event"]]) + 1

# %%
cols_order = [
    "id", "item", "category", "department", "store_code", "region",
    "yearweek", "date", "event", "n_sales", "revenue", "avg_sell_price"
]

df = df[cols_order]

# %%
df.head(5)
# Out:
#                        id  item  category  department  store_code  region  \
# 0  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 1  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 2  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 3  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 4  ACCESORIES_1_001_BOS_1     1         1           1           1       1
#
#   yearweek       date  event  n_sales  revenue  avg_sell_price
# 0   201105 2011-01-31     16        0      0.0         12.7414
# 1   201106 2011-02-07     13        0      0.0         12.7414
# 2   201107 2011-02-14     15        0      0.0         12.7414
# 3   201108 2011-02-21     16        0      0.0         12.7414
# 4   201109 2011-02-28     16        0      0.0         12.7414

# %% [markdown]
# ## 6. Creacion dataframe a predecir

# %%
def future_yearweeks_df(last_week, weeks_predict: int, as_str: bool = True) -> pd.DataFrame:
    """
    Genera un DataFrame con las próximas `weeks_predict` semanas a partir de `last_week`.
    - last_week: 'YYYYWW' como str o int (p.ej. '201617' o 201617)
    - weeks_predict: cantidad de semanas futuras a generar
    - as_str: True => yearweek como string 'YYYYWW'; False => int
    """
    last_week = str(last_week)
    year = int(last_week[:4])
    week = int(last_week[4:])

    weeks = []
    for _ in range(weeks_predict):
        week += 1
        if week > 53:  # si llegara a existir W53, pasamos a W01 del año siguiente
            week = 1
            year += 1
        val = f"{year}{str(week).zfill(2)}"
        weeks.append(val if as_str else int(val))

    return pd.DataFrame({"yearweek": weeks})

# %% [markdown]
# ### CORREGIR EVENTOS, HAY QUE CREAR EVENTOS FUTUROS EN CALENDARIO DE EVENTOS Y TOTALIZARLOS POR SEMANA PARA CRUZARLOS, USAR TRANSFOR DEL ORDINAL ENCODER, OJO, SIN FIT, SOLO TRANSFORM PARA ESTA COLUMNA

# %% [markdown]
# ### Determinar numero semanas a predecir

# %%
weeks_predict = 4
df_weeks_future = future_yearweeks_df(last_week, weeks_predict, as_str=True)

# Crear dataframe de ids únicos
df_ids = df[["id", "item", "category", "department", "store_code","region"]].drop_duplicates()

# Cross join de id's y semanas a predecir, obteniendo df_predict
try:
    # pandas 1.2+ soporta how='cross'
    df_predict = df_ids.merge(df_weeks_future, how="cross")
except TypeError:
    # fallback si tu pandas no soporta 'cross'
    df_ids["_k"] = 1
    df_weeks_future["_k"] = 1
    df_predict = df_ids.merge(df_weeks_future, on="_k").drop(columns="_k")

# df_predict tiene columnas: id, yearweek, n_sales
print(df_predict.shape)
df_predict.head()
# Out:
# (121960, 7)
#                        id  item  category  department  store_code  region  \
# 0  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 1  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 2  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 3  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 4  ACCESORIES_1_001_BOS_2     1         1           1           2       1
#
#   yearweek
# 0   201618
# 1   201619
# 2   201620
# 3   201621
# 4   201618

# %% [markdown]
# ### Asignar fecha a las nuevas semanas

# %%
# Asegurar tipos
df_predict["yearweek"] = df_predict["yearweek"].astype(str)

# Universo de semanas ISO en el rango
weeks_predict_all = sorted(df_predict["yearweek"].unique())
weeks_df_predict = pd.DataFrame(weeks_predict_all, columns=["yearweek"])

# Mapear yearweek → fecha fin de semana (lunes-based ISO) tomamos el lunes de la semana:
def iso_yearweek_to_date(yw):
    year = int(yw[:4]); week = int(yw[4:])
    # ISO: lunes de esa semana
    return pd.to_datetime(f"{year}-W{str(week).zfill(2)}-1", format="%G-W%V-%u")

weeks_df_predict["date"] = weeks_df_predict["yearweek"].map(iso_yearweek_to_date)

# %%
df_predict = df_predict.merge(weeks_df_predict, on='yearweek', how='left')
df_predict.head(3)
# Out:
#                        id  item  category  department  store_code  region  \
# 0  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 1  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 2  ACCESORIES_1_001_BOS_1     1         1           1           1       1
#
#   yearweek       date
# 0   201618 2016-05-02
# 1   201619 2016-05-09
# 2   201620 2016-05-16

# %%
df_predict.shape
# Out:
# (121960, 8)

# %% [markdown]
# ### Adicion de eventos para las futuras semanas

# %%
df_predict["event"] = "Without event"
df_predict["n_sales"] = 0
df_predict["revenue"] = 0
df_predict["avg_sell_price"] = 0

# %%
df_predict["event"] = enc_event.transform(df_predict[["event"]]) + 1

# %%
df.head(3)
# Out:
#                        id  item  category  department  store_code  region  \
# 0  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 1  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 2  ACCESORIES_1_001_BOS_1     1         1           1           1       1
#
#   yearweek       date  event  n_sales  revenue  avg_sell_price
# 0   201105 2011-01-31     16        0      0.0         12.7414
# 1   201106 2011-02-07     13        0      0.0         12.7414
# 2   201107 2011-02-14     15        0      0.0         12.7414

# %%
df_predict.head(3)
# Out:
#                        id  item  category  department  store_code  region  \
# 0  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 1  ACCESORIES_1_001_BOS_1     1         1           1           1       1
# 2  ACCESORIES_1_001_BOS_1     1         1           1           1       1
#
#   yearweek       date  event  n_sales  revenue  avg_sell_price
# 0   201618 2016-05-02     16        0        0               0
# 1   201619 2016-05-09     16        0        0               0
# 2   201620 2016-05-16     16        0        0               0

# %%
df["yearweek"] = df["yearweek"].astype(int)
df_predict["yearweek"] = df_predict["yearweek"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8354260 entries, 0 to 8354259
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              object
#  1   item            int64
#  2   category        int64
#  3   department      int64
#  4   store_code      int64
#  5   region          int64
#  6   yearweek        int64
#  7   date            datetime64[ns]
#  8   event           int64
#  9   n_sales         int64
#  10  revenue         float64
#  11  avg_sell_price  float64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(1)
# memory usage: 764.9+ MB

# %%
df_predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121960 entries, 0 to 121959
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              121960 non-null  object
#  1   item            121960 non-null  int64
#  2   category        121960 non-null  int64
#  3   department      121960 non-null  int64
#  4   store_code      121960 non-null  int64
#  5   region          121960 non-null  int64
#  6   yearweek        121960 non-null  int64
#  7   date            121960 non-null  datetime64[ns]
#  8   event           121960 non-null  int64
#  9   n_sales         121960 non-null  int64
#  10  revenue         121960 non-null  int64
#  11  avg_sell_price  121960 non-null  int64
# dtypes: datetime64[ns](1), int64(10), object(1)
# memory usage: 11.2+ MB

# %% [markdown]
# ### Union de df historico y df a predecir

# %%
rows_df = df.shape[0]
rows_predict = df_predict.shape[0]
total_rows = rows_df + rows_predict
print(f"Filas en df historico: {rows_df}")
print(f"Filas en df predecir: {rows_predict}")
print(f"Filas que deben resultar despues de union: {total_rows}")
# Out:
# Filas en df historico: 8354260
# Filas en df predecir: 121960
# Filas que deben resultar despues de union: 8476220

# %%
df = pd.concat([df, df_predict], ignore_index=True)

# %%
rows_df_concat = df.shape[0]
rows_validation = total_rows - rows_df_concat
print(f"Filas en df historico: {rows_df}")
print(f"Filas en df predecir: {rows_predict}")
print(f"Filas que deben resultar despues de union: {total_rows}")
print(f"Filas resultantes despues de union: {rows_df_concat}")
print(f"Diferencia de: {rows_validation}")
# Out:
# Filas en df historico: 8354260
# Filas en df predecir: 121960
# Filas que deben resultar despues de union: 8476220
# Filas resultantes despues de union: 8476220
# Diferencia de: 0

# %% [markdown]
# ## 7. Creacion de features para time series

# %%
def build_ts_vars(df, gb_list, target_column, agg_func, agg_func_name, nr_lags):

    assert "date" in df.columns.tolist(), "Date must be in df columns"

    new_name = "_".join(gb_list + [target_column, agg_func_name])

    # 1) Agregar a nivel semanal (date ya corresponde al lunes ISO)
    gb_df_ = (
        df.groupby(gb_list + ["date"], as_index=False)[target_column]
          .agg(agg_func)
          .rename(columns={target_column: new_name})
          .sort_values(gb_list + ["date"])
    )

    # 2) Crear lags semanales por cada grupo
    for lag in range(1, nr_lags + 1):
        gb_df_[f"{new_name}_lag{lag}"] = (
            gb_df_.groupby(gb_list, sort=False)[new_name].shift(lag)
        )

    # 4) Evitar target leakage
    print(f"Dropping columns that might cause target leakage {new_name}")
    gb_df_.drop(columns=[new_name], inplace=True)

    return gb_df_

# %%
def _resolve_agg_func(agg_func: Union[str, Callable]) -> Union[str, Callable]:
    if isinstance(agg_func, str):
        return agg_func.lower()  # "sum", "mean", etc.
    if callable(agg_func):
        # 🔽 Mapea np.sum → "sum", np.mean → "mean", etc.
        lut = {"sum": "sum", "mean": "mean", "max": "max", "min": "min", "median": "median"}
        name = getattr(agg_func, "__name__", "")
        if name in lut:
            return lut[name]
        return agg_func  # callables raros se devuelven tal cual
    raise ValueError(f"agg_func inválido: {agg_func}")

def _resolve_agg_name(agg_func: Union[str, Callable], agg_func_name: str) -> str:
    if agg_func_name:
        return agg_func_name
    if isinstance(agg_func, str):
        return agg_func.lower()
    if callable(agg_func) and getattr(agg_func, "__name__", None):
        return agg_func.__name__.lower()
    return "agg"

def generate_and_merge_features(
    df: pd.DataFrame,
    specs: List[Dict],
    *,
    verbose: bool = True,
) -> pd.DataFrame:
    """
    specs: lista de diccionarios con llaves:
      - gb_list: List[str]
      - target_column: str
      - agg_func: str | Callable
      - agg_func_name: str (opcional; si vacío se infiere)
      - nr_lags: int
    Retorna df base + todas las columnas de lags generadas en specs.
    """
    base = df.copy()

    for i, spec in enumerate(specs, start=1):
        gb_list        = spec["gb_list"]
        target_column  = spec["target_column"]
        agg_func       = _resolve_agg_func(spec["agg_func"])
        agg_func_name  = _resolve_agg_name(spec["agg_func"], spec.get("agg_func_name", ""))
        nr_lags        = int(spec["nr_lags"])

        # construir feature table con tu función base (sin resample)
        feats = build_ts_vars(
            df=base,
            gb_list=gb_list,
            target_column=target_column,
            agg_func=agg_func,
            agg_func_name=agg_func_name,
            nr_lags=nr_lags,
        )
        # claves de unión para este feature set
        on_keys = gb_list + ["date"]

        if verbose:
            created_cols = [c for c in feats.columns if c.endswith(tuple([f"_lag{k}" for k in range(1, nr_lags+1)]))]
            print(f"[{i}/{len(specs)}] Merge on {on_keys} | new cols: {created_cols[:5]}{' ...' if len(created_cols)>5 else ''}")

        # merge left al df base
        base = base.merge(feats, on=on_keys, how="left")

    return base

# %% [markdown]
# #### Configuracion de features

# %% [markdown]
# Benchmark:
# 1. Store_code/Revenue/sum/l=5 - store_code,department/n_sales/mean/l=4 --> RMSE 18.94

# %%
features = [
    {
        "gb_list": ["item", "store_code"],
        "target_column": "revenue",
        "agg_func": "mean",
        "agg_func_name": "",  # se inferirá "sum"
        "nr_lags": 3,
    },
    {
        "gb_list": ["store_code", "item"],
        "target_column": "n_sales",
        "agg_func": "sum",
        "agg_func_name": "",  # se inferirá "mean"
        "nr_lags": 12,
    },
    {
        "gb_list": ["department", "store_code"],
        "target_column": "n_sales",
        "agg_func": "max",
        "agg_func_name": "",  # se inferirá "mean"
        "nr_lags": 2,
    },
    {
        "gb_list": ["region", "store_code"],
        "target_column": "n_sales",
        "agg_func": "sum",
        "agg_func_name": "",  # se inferirá "mean"
        "nr_lags": 3,
    },
    # agrega todas las que quieras...
]

# %%
df_features = generate_and_merge_features(df, features, verbose=True)
df_col = df.shape[1]
df_feat_col = df_features.shape[1]
dif_cols = df_feat_col-df_col
print(f"Se han creado {dif_cols} nuevas variables")
# Out:
# Dropping columns that might cause target leakage item_store_code_revenue_mean
# [1/4] Merge on ['item', 'store_code', 'date'] | new cols: ['item_store_code_revenue_mean_lag1', 'item_store_code_revenue_mean_lag2', 'item_store_code_revenue_mean_lag3']
# Dropping columns that might cause target leakage store_code_item_n_sales_sum
# [2/4] Merge on ['store_code', 'item', 'date'] | new cols: ['store_code_item_n_sales_sum_lag1', 'store_code_item_n_sales_sum_lag2', 'store_code_item_n_sales_sum_lag3', 'store_code_item_n_sales_sum_lag4', 'store_code_item_n_sales_sum_lag5'] ...
# Dropping columns that might cause target leakage department_store_code_n_sales_max
# [3/4] Merge on ['department', 'store_code', 'date'] | new cols: ['department_store_code_n_sales_max_lag1', 'department_store_code_n_sales_max_lag2']
# Dropping columns that might cause target leakage region_store_code_n_sales_sum
# [4/4] Merge on ['region', 'store_code', 'date'] | new cols: ['region_store_code_n_sales_sum_lag1', 'region_store_code_n_sales_sum_lag2', 'region_store_code_n_sales_sum_lag3']
# Se han creado 20 nuevas variables

# %%
df_features.tail(5)
# Out:
#                               id  item  category  department  store_code  \
# 8476215  SUPERMARKET_3_827_PHI_2  3049         3           7           9
# 8476216  SUPERMARKET_3_827_PHI_3  3049         3           7          10
# 8476217  SUPERMARKET_3_827_PHI_3  3049         3           7          10
# 8476218  SUPERMARKET_3_827_PHI_3  3049         3           7          10
# 8476219  SUPERMARKET_3_827_PHI_3  3049         3           7          10
#
#          region  yearweek       date  event  n_sales  ...  \
# 8476215       3    201621 2016-05-23     16        0  ...
# 8476216       3    201618 2016-05-02     16        0  ...
# 8476217       3    201619 2016-05-09     16        0  ...
# 8476218       3    201620 2016-05-16     16        0  ...
# 8476219       3    201621 2016-05-23     16        0  ...
#
#          store_code_item_n_sales_sum_lag8  store_code_item_n_sales_sum_lag9  \
# 8476215                              24.0                               7.0
# 8476216                               5.0                              16.0
# 8476217                              16.0                               5.0
# 8476218                              17.0                              16.0
# 8476219                              23.0                              17.0
#
#          store_code_item_n_sales_sum_lag10  store_code_item_n_sales_sum_lag11  \
# 8476215                               28.0                               24.0
# 8476216                                7.0                               10.0
# 8476217                               16.0                                7.0
# 8476218                                5.0                               16.0
# 8476219                               16.0                                5.0
#
#          store_code_item_n_sales_sum_lag12  \
# 8476215                               19.0
# 8476216                               17.0
# 8476217                               10.0
# 8476218                                7.0
# 8476219                               16.0
#
#          department_store_code_n_sales_max_lag1  \
# 8476215                                     0.0
# 8476216                                   262.0
# 8476217                                     0.0
# 8476218                                     0.0
# 8476219                                     0.0
#
#          department_store_code_n_sales_max_lag2  \
# 8476215                                     0.0
# 8476216                                   589.0
# 8476217                                   262.0
# 8476218                                     0.0
# 8476219                                     0.0
#
#          region_store_code_n_sales_sum_lag1  \
# 8476215                                 0.0
# 8476216                              9011.0
# 8476217                                 0.0
# 8476218                                 0.0
# 8476219                                 0.0
#
#          region_store_code_n_sales_sum_lag2  \
# 8476215                                 0.0
# 8476216                             26518.0
# 8476217                              9011.0
# 8476218                                 0.0
# 8476219                                 0.0
#
#          region_store_code_n_sales_sum_lag3
# 8476215                                 0.0
# 8476216                             30192.0
# 8476217                             26518.0
# 8476218                              9011.0
# 8476219                                 0.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## 8. Split Train, Test y Predict

# %%
df_features.columns.tolist()
# Out:
# ['id',
#  'item',
#  'category',
#  'department',
#  'store_code',
#  'region',
#  'yearweek',
#  'date',
#  'event',
#  'n_sales',
#  'revenue',
#  'avg_sell_price',
#  'item_store_code_revenue_mean_lag1',
#  'item_store_code_revenue_mean_lag2',
#  'item_store_code_revenue_mean_lag3',
#  'store_code_item_n_sales_sum_lag1',
#  'store_code_item_n_sales_sum_lag2',
#  'store_code_item_n_sales_sum_lag3',
#  'store_code_item_n_sales_sum_lag4',
#  'store_code_item_n_sales_sum_lag5',
#  'store_code_item_n_sales_sum_lag6',
#  'store_code_item_n_sales_sum_lag7',
#  'store_code_item_n_sales_sum_lag8',
#  'store_code_item_n_sales_sum_lag9',
#  'store_code_item_n_sales_sum_lag10',
#  'store_code_item_n_sales_sum_lag11',
#  'store_code_item_n_sales_sum_lag12',
#  'department_store_code_n_sales_max_lag1',
#  'department_store_code_n_sales_max_lag2',
#  'region_store_code_n_sales_sum_lag1',
#  'region_store_code_n_sales_sum_lag2',
#  'region_store_code_n_sales_sum_lag3']

# %%
df_features.set_index("id", inplace=True)

# %%
weeks = sorted(df_features["date"].unique())
weeks
# Out:
# [Timestamp('2011-01-31 00:00:00'),
#  Timestamp('2011-02-07 00:00:00'),
#  Timestamp('2011-02-14 00:00:00'),
#  Timestamp('2011-02-21 00:00:00'),
#  Timestamp('2011-02-28 00:00:00'),
#  Timestamp('2011-03-07 00:00:00'),
#  Timestamp('2011-03-14 00:00:00'),
#  Timestamp('2011-03-21 00:00:00'),
#  Timestamp('2011-03-28 00:00:00'),
#  Timestamp('2011-04-04 00:00:00'),
#  Timestamp('2011-04-11 00:00:00'),
#  Timestamp('2011-04-18 00:00:00'),
#  Timestamp('2011-04-25 00:00:00'),
#  Timestamp('2011-05-02 00:00:00'),
#  Timestamp('2011-05-09 00:00:00'),
#  Timestamp('2011-05-16 00:00:00'),
#  Timestamp('2011-05-23 00:00:00'),
#  Timestamp('2011-05-30 00:00:00'),
#  Timestamp('2011-06-06 00:00:00'),
#  Timestamp('2011-06-13 00:00:00'),
#  Timestamp('2011-06-20 00:00:00'),
#  Timestamp('2011-06-27 00:00:00'),
#  Timestamp('2011-07-04 00:00:00'),
#  Timestamp('2011-07-11 00:00:00'),
#  Timestamp('2011-07-18 00:00:00'),
#  Timestamp('2011-07-25 00:00:00'),
#  Timestamp('2011-08-01 00:00:00'),
#  Timestamp('2011-08-08 00:00:00'),
#  Timestamp('2011-08-15 00:00:00'),
#  Timestamp('2011-08-22 00:00:00'),
#  Timestamp('2011-08-29 00:00:00'),
#  Timestamp('2011-09-05 00:00:00'),
#  Timestamp('2011-09-12 00:00:00'),
#  Timestamp('2011-09-19 00:00:00'),
#  Timestamp('2011-09-26 00:00:00'),
#  Timestamp('2011-10-03 00:00:00'),
#  Timestamp('2011-10-10 00:00:00'),
#  Timestamp('2011-10-17 00:00:00'),
#  Timestamp('2011-10-24 00:00:00'),
#  Timestamp('2011-10-31 00:00:00'),
#  Timestamp('2011-11-07 00:00:00'),
#  Timestamp('2011-11-14 00:00:00'),
#  Timestamp('2011-11-21 00:00:00'),
#  Timestamp('2011-11-28 00:00:00'),
#  Timestamp('2011-12-05 00:00:00'),
#  Timestamp('2011-12-12 00:00:00'),
#  Timestamp('2011-12-19 00:00:00'),
#  Timestamp('2011-12-26 00:00:00'),
#  Timestamp('2012-01-02 00:00:00'),
#  Timestamp('2012-01-09 00:00:00'),
#  Timestamp('2012-01-16 00:00:00'),
#  Timestamp('2012-01-23 00:00:00'),
#  Timestamp('2012-01-30 00:00:00'),
#  Timestamp('2012-02-06 00:00:00'),
#  Timestamp('2012-02-13 00:00:00'),
#  Timestamp('2012-02-20 00:00:00'),
#  Timestamp('2012-02-27 00:00:00'),
#  Timestamp('2012-03-05 00:00:00'),
#  Timestamp('2012-03-12 00:00:00'),
#  Timestamp('2012-03-19 00:00:00'),
#  Timestamp('2012-03-26 00:00:00'),
#  Timestamp('2012-04-02 00:00:00'),
#  Timestamp('2012-04-09 00:00:00'),
#  Timestamp('2012-04-16 00:00:00'),
#  Timestamp('2012-04-23 00:00:00'),
#  Timestamp('2012-04-30 00:00:00'),
#  Timestamp('2012-05-07 00:00:00'),
#  Timestamp('2012-05-14 00:00:00'),
#  Timestamp('2012-05-21 00:00:00'),
#  Timestamp('2012-05-28 00:00:00'),
#  Timestamp('2012-06-04 00:00:00'),
#  Timestamp('2012-06-11 00:00:00'),
#  Timestamp('2012-06-18 00:00:00'),
#  Timestamp('2012-06-25 00:00:00'),
#  Timestamp('2012-07-02 00:00:00'),
#  Timestamp('2012-07-09 00:00:00'),
#  Timestamp('2012-07-16 00:00:00'),
#  Timestamp('2012-07-23 00:00:00'),
#  Timestamp('2012-07-30 00:00:00'),
#  Timestamp('2012-08-06 00:00:00'),
#  Timestamp('2012-08-13 00:00:00'),
#  Timestamp('2012-08-20 00:00:00'),
#  Timestamp('2012-08-27 00:00:00'),
#  Timestamp('2012-09-03 00:00:00'),
#  Timestamp('2012-09-10 00:00:00'),
#  Timestamp('2012-09-17 00:00:00'),
#  Timestamp('2012-09-24 00:00:00'),
#  Timestamp('2012-10-01 00:00:00'),
#  Timestamp('2012-10-08 00:00:00'),
#  Timestamp('2012-10-15 00:00:00'),
#  Timestamp('2012-10-22 00:00:00'),
#  Timestamp('2012-10-29 00:00:00'),
#  Timestamp('2012-11-05 00:00:00'),
#  Timestamp('2012-11-12 00:00:00'),
#  Timestamp('2012-11-19 00:00:00'),
#  Timestamp('2012-11-26 00:00:00'),
#  Timestamp('2012-12-03 00:00:00'),
#  Timestamp('2012-12-10 00:00:00'),
#  Timestamp('2012-12-17 00:00:00'),
#  Timestamp('2012-12-24 00:00:00'),
#  Timestamp('2012-12-31 00:00:00'),
#  Timestamp('2013-01-07 00:00:00'),
#  Timestamp('2013-01-14 00:00:00'),
#  Timestamp('2013-01-21 00:00:00'),
#  Timestamp('2013-01-28 00:00:00'),
#  Timestamp('2013-02-04 00:00:00'),
#  Timestamp('2013-02-11 00:00:00'),
#  Timestamp('2013-02-18 00:00:00'),
#  Timestamp('2013-02-25 00:00:00'),
#  Timestamp('2013-03-04 00:00:00'),
#  Timestamp('2013-03-11 00:00:00'),
#  Timestamp('2013-03-18 00:00:00'),
#  Timestamp('2013-03-25 00:00:00'),
#  Timestamp('2013-04-01 00:00:00'),
#  Timestamp('2013-04-08 00:00:00'),
#  Timestamp('2013-04-15 00:00:00'),
#  Timestamp('2013-04-22 00:00:00'),
#  Timestamp('2013-04-29 00:00:00'),
#  Timestamp('2013-05-06 00:00:00'),
#  Timestamp('2013-05-13 00:00:00'),
#  Timestamp('2013-05-20 00:00:00'),
#  Timestamp('2013-05-27 00:00:00'),
#  Timestamp('2013-06-03 00:00:00'),
#  Timestamp('2013-06-10 00:00:00'),
#  Timestamp('2013-06-17 00:00:00'),
#  Timestamp('2013-06-24 00:00:00'),
#  Timestamp('2013-07-01 00:00:00'),
#  Timestamp('2013-07-08 00:00:00'),
#  Timestamp('2013-07-15 00:00:00'),
#  Timestamp('2013-07-22 00:00:00'),
#  Timestamp('2013-07-29 00:00:00'),
#  Timestamp('2013-08-05 00:00:00'),
#  Timestamp('2013-08-12 00:00:00'),
#  Timestamp('2013-08-19 00:00:00'),
#  Timestamp('2013-08-26 00:00:00'),
#  Timestamp('2013-09-02 00:00:00'),
#  Timestamp('2013-09-09 00:00:00'),
#  Timestamp('2013-09-16 00:00:00'),
#  Timestamp('2013-09-23 00:00:00'),
#  Timestamp('2013-09-30 00:00:00'),
#  Timestamp('2013-10-07 00:00:00'),
#  Timestamp('2013-10-14 00:00:00'),
#  Timestamp('2013-10-21 00:00:00'),
#  Timestamp('2013-10-28 00:00:00'),
#  Timestamp('2013-11-04 00:00:00'),
#  Timestamp('2013-11-11 00:00:00'),
#  Timestamp('2013-11-18 00:00:00'),
#  Timestamp('2013-11-25 00:00:00'),
#  Timestamp('2013-12-02 00:00:00'),
#  Timestamp('2013-12-09 00:00:00'),
#  Timestamp('2013-12-16 00:00:00'),
#  Timestamp('2013-12-23 00:00:00'),
#  Timestamp('2013-12-30 00:00:00'),
#  Timestamp('2014-01-06 00:00:00'),
#  Timestamp('2014-01-13 00:00:00'),
#  Timestamp('2014-01-20 00:00:00'),
#  Timestamp('2014-01-27 00:00:00'),
#  Timestamp('2014-02-03 00:00:00'),
#  Timestamp('2014-02-10 00:00:00'),
#  Timestamp('2014-02-17 00:00:00'),
#  Timestamp('2014-02-24 00:00:00'),
#  Timestamp('2014-03-03 00:00:00'),
#  Timestamp('2014-03-10 00:00:00'),
#  Timestamp('2014-03-17 00:00:00'),
#  Timestamp('2014-03-24 00:00:00'),
#  Timestamp('2014-03-31 00:00:00'),
#  Timestamp('2014-04-07 00:00:00'),
#  Timestamp('2014-04-14 00:00:00'),
#  Timestamp('2014-04-21 00:00:00'),
#  Timestamp('2014-04-28 00:00:00'),
#  Timestamp('2014-05-05 00:00:00'),
#  Timestamp('2014-05-12 00:00:00'),
#  Timestamp('2014-05-19 00:00:00'),
#  Timestamp('2014-05-26 00:00:00'),
#  Timestamp('2014-06-02 00:00:00'),
#  Timestamp('2014-06-09 00:00:00'),
#  Timestamp('2014-06-16 00:00:00'),
#  Timestamp('2014-06-23 00:00:00'),
#  Timestamp('2014-06-30 00:00:00'),
#  Timestamp('2014-07-07 00:00:00'),
#  Timestamp('2014-07-14 00:00:00'),
#  Timestamp('2014-07-21 00:00:00'),
#  Timestamp('2014-07-28 00:00:00'),
#  Timestamp('2014-08-04 00:00:00'),
#  Timestamp('2014-08-11 00:00:00'),
#  Timestamp('2014-08-18 00:00:00'),
#  Timestamp('2014-08-25 00:00:00'),
#  Timestamp('2014-09-01 00:00:00'),
#  Timestamp('2014-09-08 00:00:00'),
#  Timestamp('2014-09-15 00:00:00'),
#  Timestamp('2014-09-22 00:00:00'),
#  Timestamp('2014-09-29 00:00:00'),
#  Timestamp('2014-10-06 00:00:00'),
#  Timestamp('2014-10-13 00:00:00'),
#  Timestamp('2014-10-20 00:00:00'),
#  Timestamp('2014-10-27 00:00:00'),
#  Timestamp('2014-11-03 00:00:00'),
#  Timestamp('2014-11-10 00:00:00'),
#  Timestamp('2014-11-17 00:00:00'),
#  Timestamp('2014-11-24 00:00:00'),
#  Timestamp('2014-12-01 00:00:00'),
#  Timestamp('2014-12-08 00:00:00'),
#  Timestamp('2014-12-15 00:00:00'),
#  Timestamp('2014-12-22 00:00:00'),
#  Timestamp('2014-12-29 00:00:00'),
#  Timestamp('2015-01-05 00:00:00'),
#  Timestamp('2015-01-12 00:00:00'),
#  Timestamp('2015-01-19 00:00:00'),
#  Timestamp('2015-01-26 00:00:00'),
#  Timestamp('2015-02-02 00:00:00'),
#  Timestamp('2015-02-09 00:00:00'),
#  Timestamp('2015-02-16 00:00:00'),
#  Timestamp('2015-02-23 00:00:00'),
#  Timestamp('2015-03-02 00:00:00'),
#  Timestamp('2015-03-09 00:00:00'),
#  Timestamp('2015-03-16 00:00:00'),
#  Timestamp('2015-03-23 00:00:00'),
#  Timestamp('2015-03-30 00:00:00'),
#  Timestamp('2015-04-06 00:00:00'),
#  Timestamp('2015-04-13 00:00:00'),
#  Timestamp('2015-04-20 00:00:00'),
#  Timestamp('2015-04-27 00:00:00'),
#  Timestamp('2015-05-04 00:00:00'),
#  Timestamp('2015-05-11 00:00:00'),
#  Timestamp('2015-05-18 00:00:00'),
#  Timestamp('2015-05-25 00:00:00'),
#  Timestamp('2015-06-01 00:00:00'),
#  Timestamp('2015-06-08 00:00:00'),
#  Timestamp('2015-06-15 00:00:00'),
#  Timestamp('2015-06-22 00:00:00'),
#  Timestamp('2015-06-29 00:00:00'),
#  Timestamp('2015-07-06 00:00:00'),
#  Timestamp('2015-07-13 00:00:00'),
#  Timestamp('2015-07-20 00:00:00'),
#  Timestamp('2015-07-27 00:00:00'),
#  Timestamp('2015-08-03 00:00:00'),
#  Timestamp('2015-08-10 00:00:00'),
#  Timestamp('2015-08-17 00:00:00'),
#  Timestamp('2015-08-24 00:00:00'),
#  Timestamp('2015-08-31 00:00:00'),
#  Timestamp('2015-09-07 00:00:00'),
#  Timestamp('2015-09-14 00:00:00'),
#  Timestamp('2015-09-21 00:00:00'),
#  Timestamp('2015-09-28 00:00:00'),
#  Timestamp('2015-10-05 00:00:00'),
#  Timestamp('2015-10-12 00:00:00'),
#  Timestamp('2015-10-19 00:00:00'),
#  Timestamp('2015-10-26 00:00:00'),
#  Timestamp('2015-11-02 00:00:00'),
#  Timestamp('2015-11-09 00:00:00'),
#  Timestamp('2015-11-16 00:00:00'),
#  Timestamp('2015-11-23 00:00:00'),
#  Timestamp('2015-11-30 00:00:00'),
#  Timestamp('2015-12-07 00:00:00'),
#  Timestamp('2015-12-14 00:00:00'),
#  Timestamp('2015-12-21 00:00:00'),
#  Timestamp('2016-01-04 00:00:00'),
#  Timestamp('2016-01-11 00:00:00'),
#  Timestamp('2016-01-18 00:00:00'),
#  Timestamp('2016-01-25 00:00:00'),
#  Timestamp('2016-02-01 00:00:00'),
#  Timestamp('2016-02-08 00:00:00'),
#  Timestamp('2016-02-15 00:00:00'),
#  Timestamp('2016-02-22 00:00:00'),
#  Timestamp('2016-02-29 00:00:00'),
#  Timestamp('2016-03-07 00:00:00'),
#  Timestamp('2016-03-14 00:00:00'),
#  Timestamp('2016-03-21 00:00:00'),
#  Timestamp('2016-03-28 00:00:00'),
#  Timestamp('2016-04-04 00:00:00'),
#  Timestamp('2016-04-11 00:00:00'),
#  Timestamp('2016-04-18 00:00:00'),
#  Timestamp('2016-04-25 00:00:00'),
#  Timestamp('2016-05-02 00:00:00'),
#  Timestamp('2016-05-09 00:00:00'),
#  Timestamp('2016-05-16 00:00:00'),
#  Timestamp('2016-05-23 00:00:00')]

# %%
train_weeks = weeks[:-8]
test_weeks = weeks[-8:-4]
predict_weeks = weeks[-4:]

print(f"Semanas para train: {train_weeks[:2]} - ... - {train_weeks[-2:]}\n")
print(f"Semanas para test: {test_weeks}\n")
print(f"Semanas para predict: {predict_weeks}")
# Out:
# Semanas para train: [Timestamp('2011-01-31 00:00:00'), Timestamp('2011-02-07 00:00:00')] - ... - [Timestamp('2016-03-21 00:00:00'), Timestamp('2016-03-28 00:00:00')]
#
# Semanas para test: [Timestamp('2016-04-04 00:00:00'), Timestamp('2016-04-11 00:00:00'), Timestamp('2016-04-18 00:00:00'), Timestamp('2016-04-25 00:00:00')]
#
# Semanas para predict: [Timestamp('2016-05-02 00:00:00'), Timestamp('2016-05-09 00:00:00'), Timestamp('2016-05-16 00:00:00'), Timestamp('2016-05-23 00:00:00')]

# %%
predict_weeks
# Out:
# [Timestamp('2016-05-02 00:00:00'),
#  Timestamp('2016-05-09 00:00:00'),
#  Timestamp('2016-05-16 00:00:00'),
#  Timestamp('2016-05-23 00:00:00')]

# %%
COLS_DROP = ["date", "revenue", "n_sales", "avg_sell_price"]

# %%
X_train = df_features[df_features["date"].isin(train_weeks)].drop(columns = COLS_DROP, axis = 1)
X_test = df_features[df_features["date"].isin(test_weeks)].drop(columns = COLS_DROP, axis = 1)
X_pred = df_features[df_features["date"].isin(predict_weeks)].drop(columns = COLS_DROP, axis = 1)

# %%
y_train = df_features[df_features["date"].isin(train_weeks)]["n_sales"]
y_test = df_features[df_features["date"].isin(test_weeks)]["n_sales"]
y_pred = df_features[df_features["date"].isin(predict_weeks)]["n_sales"]

# %%
X_test.head(3)
# Out:
#                         item  category  department  store_code  region  \
# id
# ACCESORIES_1_001_BOS_1     1         1           1           1       1
# ACCESORIES_1_001_BOS_1     1         1           1           1       1
# ACCESORIES_1_001_BOS_1     1         1           1           1       1
#
#                         yearweek  event  item_store_code_revenue_mean_lag1  \
# id
# ACCESORIES_1_001_BOS_1    201614     16                            21.9716
# ACCESORIES_1_001_BOS_1    201615     16                            21.9716
# ACCESORIES_1_001_BOS_1    201616     16                            21.9716
#
#                         item_store_code_revenue_mean_lag2  \
# id
# ACCESORIES_1_001_BOS_1                            32.9574
# ACCESORIES_1_001_BOS_1                            21.9716
# ACCESORIES_1_001_BOS_1                            21.9716
#
#                         item_store_code_revenue_mean_lag3  ...  \
# id                                                         ...
# ACCESORIES_1_001_BOS_1                            21.9716  ...
# ACCESORIES_1_001_BOS_1                            32.9574  ...
# ACCESORIES_1_001_BOS_1                            21.9716  ...
#
#                         store_code_item_n_sales_sum_lag8  \
# id
# ACCESORIES_1_001_BOS_1                               0.0
# ACCESORIES_1_001_BOS_1                               0.0
# ACCESORIES_1_001_BOS_1                               4.0
#
#                         store_code_item_n_sales_sum_lag9  \
# id
# ACCESORIES_1_001_BOS_1                               3.0
# ACCESORIES_1_001_BOS_1                               0.0
# ACCESORIES_1_001_BOS_1                               0.0
#
#                         store_code_item_n_sales_sum_lag10  \
# id
# ACCESORIES_1_001_BOS_1                                3.0
# ACCESORIES_1_001_BOS_1                                3.0
# ACCESORIES_1_001_BOS_1                                0.0
#
#                         store_code_item_n_sales_sum_lag11  \
# id
# ACCESORIES_1_001_BOS_1                                0.0
# ACCESORIES_1_001_BOS_1                                3.0
# ACCESORIES_1_001_BOS_1                                3.0
#
#                         store_code_item_n_sales_sum_lag12  \
# id
# ACCESORIES_1_001_BOS_1                                0.0
# ACCESORIES_1_001_BOS_1                                0.0
# ACCESORIES_1_001_BOS_1                                3.0
#
#                         department_store_code_n_sales_max_lag1  \
# id
# ACCESORIES_1_001_BOS_1                                    67.0
# ACCESORIES_1_001_BOS_1                                    64.0
# ACCESORIES_1_001_BOS_1                                    60.0
#
#                         department_store_code_n_sales_max_lag2  \
# id
# ACCESORIES_1_001_BOS_1                                    60.0
# ACCESORIES_1_001_BOS_1                                    67.0
# ACCESORIES_1_001_BOS_1                                    64.0
#
#                         region_store_code_n_sales_sum_lag1  \
# id
# ACCESORIES_1_001_BOS_1                             22958.0
# ACCESORIES_1_001_BOS_1                             24142.0
# ACCESORIES_1_001_BOS_1                             23273.0
#
#                         region_store_code_n_sales_sum_lag2  \
# id
# ACCESORIES_1_001_BOS_1                             22309.0
# ACCESORIES_1_001_BOS_1                             22958.0
# ACCESORIES_1_001_BOS_1                             24142.0
#
#                         region_store_code_n_sales_sum_lag3
# id
# ACCESORIES_1_001_BOS_1                             24371.0
# ACCESORIES_1_001_BOS_1                             22309.0
# ACCESORIES_1_001_BOS_1                             22958.0
#
# [3 rows x 27 columns]

# %%
X_train.head(3)
# Out:
#                         item  category  department  store_code  region  \
# id
# ACCESORIES_1_001_BOS_1     1         1           1           1       1
# ACCESORIES_1_001_BOS_1     1         1           1           1       1
# ACCESORIES_1_001_BOS_1     1         1           1           1       1
#
#                         yearweek  event  item_store_code_revenue_mean_lag1  \
# id
# ACCESORIES_1_001_BOS_1    201105     16                                NaN
# ACCESORIES_1_001_BOS_1    201106     13                                0.0
# ACCESORIES_1_001_BOS_1    201107     15                                0.0
#
#                         item_store_code_revenue_mean_lag2  \
# id
# ACCESORIES_1_001_BOS_1                                NaN
# ACCESORIES_1_001_BOS_1                                NaN
# ACCESORIES_1_001_BOS_1                                0.0
#
#                         item_store_code_revenue_mean_lag3  ...  \
# id                                                         ...
# ACCESORIES_1_001_BOS_1                                NaN  ...
# ACCESORIES_1_001_BOS_1                                NaN  ...
# ACCESORIES_1_001_BOS_1                                NaN  ...
#
#                         store_code_item_n_sales_sum_lag8  \
# id
# ACCESORIES_1_001_BOS_1                               NaN
# ACCESORIES_1_001_BOS_1                               NaN
# ACCESORIES_1_001_BOS_1                               NaN
#
#                         store_code_item_n_sales_sum_lag9  \
# id
# ACCESORIES_1_001_BOS_1                               NaN
# ACCESORIES_1_001_BOS_1                               NaN
# ACCESORIES_1_001_BOS_1                               NaN
#
#                         store_code_item_n_sales_sum_lag10  \
# id
# ACCESORIES_1_001_BOS_1                                NaN
# ACCESORIES_1_001_BOS_1                                NaN
# ACCESORIES_1_001_BOS_1                                NaN
#
#                         store_code_item_n_sales_sum_lag11  \
# id
# ACCESORIES_1_001_BOS_1                                NaN
# ACCESORIES_1_001_BOS_1                                NaN
# ACCESORIES_1_001_BOS_1                                NaN
#
#                         store_code_item_n_sales_sum_lag12  \
# id
# ACCESORIES_1_001_BOS_1                                NaN
# ACCESORIES_1_001_BOS_1                                NaN
# ACCESORIES_1_001_BOS_1                                NaN
#
#                         department_store_code_n_sales_max_lag1  \
# id
# ACCESORIES_1_001_BOS_1                                     NaN
# ACCESORIES_1_001_BOS_1                                    52.0
# ACCESORIES_1_001_BOS_1                                    66.0
#
#                         department_store_code_n_sales_max_lag2  \
# id
# ACCESORIES_1_001_BOS_1                                     NaN
# ACCESORIES_1_001_BOS_1                                     NaN
# ACCESORIES_1_001_BOS_1                                    52.0
#
#                         region_store_code_n_sales_sum_lag1  \
# id
# ACCESORIES_1_001_BOS_1                                 NaN
# ACCESORIES_1_001_BOS_1                             15442.0
# ACCESORIES_1_001_BOS_1                             15788.0
#
#                         region_store_code_n_sales_sum_lag2  \
# id
# ACCESORIES_1_001_BOS_1                                 NaN
# ACCESORIES_1_001_BOS_1                                 NaN
# ACCESORIES_1_001_BOS_1                             15442.0
#
#                         region_store_code_n_sales_sum_lag3
# id
# ACCESORIES_1_001_BOS_1                                 NaN
# ACCESORIES_1_001_BOS_1                                 NaN
# ACCESORIES_1_001_BOS_1                                 NaN
#
# [3 rows x 27 columns]

# %%
X_pred.head(3)
# Out:
#                         item  category  department  store_code  region  \
# id
# ACCESORIES_1_001_BOS_1     1         1           1           1       1
# ACCESORIES_1_001_BOS_1     1         1           1           1       1
# ACCESORIES_1_001_BOS_1     1         1           1           1       1
#
#                         yearweek  event  item_store_code_revenue_mean_lag1  \
# id
# ACCESORIES_1_001_BOS_1    201618     16                            21.9716
# ACCESORIES_1_001_BOS_1    201619     16                             0.0000
# ACCESORIES_1_001_BOS_1    201620     16                             0.0000
#
#                         item_store_code_revenue_mean_lag2  \
# id
# ACCESORIES_1_001_BOS_1                            21.9716
# ACCESORIES_1_001_BOS_1                            21.9716
# ACCESORIES_1_001_BOS_1                             0.0000
#
#                         item_store_code_revenue_mean_lag3  ...  \
# id                                                         ...
# ACCESORIES_1_001_BOS_1                            21.9716  ...
# ACCESORIES_1_001_BOS_1                            21.9716  ...
# ACCESORIES_1_001_BOS_1                            21.9716  ...
#
#                         store_code_item_n_sales_sum_lag8  \
# id
# ACCESORIES_1_001_BOS_1                               3.0
# ACCESORIES_1_001_BOS_1                               2.0
# ACCESORIES_1_001_BOS_1                               3.0
#
#                         store_code_item_n_sales_sum_lag9  \
# id
# ACCESORIES_1_001_BOS_1                               2.0
# ACCESORIES_1_001_BOS_1                               3.0
# ACCESORIES_1_001_BOS_1                               2.0
#
#                         store_code_item_n_sales_sum_lag10  \
# id
# ACCESORIES_1_001_BOS_1                                4.0
# ACCESORIES_1_001_BOS_1                                2.0
# ACCESORIES_1_001_BOS_1                                3.0
#
#                         store_code_item_n_sales_sum_lag11  \
# id
# ACCESORIES_1_001_BOS_1                                0.0
# ACCESORIES_1_001_BOS_1                                4.0
# ACCESORIES_1_001_BOS_1                                2.0
#
#                         store_code_item_n_sales_sum_lag12  \
# id
# ACCESORIES_1_001_BOS_1                                0.0
# ACCESORIES_1_001_BOS_1                                0.0
# ACCESORIES_1_001_BOS_1                                4.0
#
#                         department_store_code_n_sales_max_lag1  \
# id
# ACCESORIES_1_001_BOS_1                                    36.0
# ACCESORIES_1_001_BOS_1                                     0.0
# ACCESORIES_1_001_BOS_1                                     0.0
#
#                         department_store_code_n_sales_max_lag2  \
# id
# ACCESORIES_1_001_BOS_1                                    49.0
# ACCESORIES_1_001_BOS_1                                    36.0
# ACCESORIES_1_001_BOS_1                                     0.0
#
#                         region_store_code_n_sales_sum_lag1  \
# id
# ACCESORIES_1_001_BOS_1                              7733.0
# ACCESORIES_1_001_BOS_1                                 0.0
# ACCESORIES_1_001_BOS_1                                 0.0
#
#                         region_store_code_n_sales_sum_lag2  \
# id
# ACCESORIES_1_001_BOS_1                             23282.0
# ACCESORIES_1_001_BOS_1                              7733.0
# ACCESORIES_1_001_BOS_1                                 0.0
#
#                         region_store_code_n_sales_sum_lag3
# id
# ACCESORIES_1_001_BOS_1                             23273.0
# ACCESORIES_1_001_BOS_1                             23282.0
# ACCESORIES_1_001_BOS_1                              7733.0
#
# [3 rows x 27 columns]

# %%
y_train.head(3)
# Out:
# id
# ACCESORIES_1_001_BOS_1    0
# ACCESORIES_1_001_BOS_1    0
# ACCESORIES_1_001_BOS_1    0
# Name: n_sales, dtype: int64

# %%
y_test.head(3)
# Out:
# id
# ACCESORIES_1_001_BOS_1    2
# ACCESORIES_1_001_BOS_1    2
# ACCESORIES_1_001_BOS_1    2
# Name: n_sales, dtype: int64

# %%
y_pred.head(3)
# Out:
# id
# ACCESORIES_1_001_BOS_1    0
# ACCESORIES_1_001_BOS_1    0
# ACCESORIES_1_001_BOS_1    0
# Name: n_sales, dtype: int64

# %% [markdown]
# ## 9. Entrenar modelos

# %%
model = xgb.XGBRegressor(max_depth = 5, eval_metric = "rmse", seed = 175)

# %%
model.fit(
    X = X_train,
    y = y_train,
    eval_set = [(X_train, y_train), (X_test, y_test)],
    verbose = True
)
# Out:
# [0]	validation_0-rmse:18.50071	validation_1-rmse:14.88345
# [1]	validation_0-rmse:15.20148	validation_1-rmse:12.05950
# [2]	validation_0-rmse:13.17735	validation_1-rmse:10.59536
# [3]	validation_0-rmse:11.93239	validation_1-rmse:9.97528
# [4]	validation_0-rmse:11.15283	validation_1-rmse:9.87323
# [5]	validation_0-rmse:10.75415	validation_1-rmse:9.95004
# [6]	validation_0-rmse:10.46223	validation_1-rmse:10.03746
# [7]	validation_0-rmse:10.30399	validation_1-rmse:10.11124
# [8]	validation_0-rmse:10.14569	validation_1-rmse:10.15194
# [9]	validation_0-rmse:10.06805	validation_1-rmse:10.20055
# [10]	validation_0-rmse:10.01728	validation_1-rmse:10.22850
# [11]	validation_0-rmse:9.92944	validation_1-rmse:10.27588
# [12]	validation_0-rmse:9.90545	validation_1-rmse:10.28032
# [13]	validation_0-rmse:9.88211	validation_1-rmse:10.29022
# [14]	validation_0-rmse:9.85245	validation_1-rmse:10.29348
# [15]	validation_0-rmse:9.80350	validation_1-rmse:10.27242
# [16]	validation_0-rmse:9.80046	validation_1-rmse:10.27242
# [17]	validation_0-rmse:9.77659	validation_1-rmse:10.26672
# [18]	validation_0-rmse:9.76191	validation_1-rmse:10.26797
# [19]	validation_0-rmse:9.76008	validation_1-rmse:10.26798
# [20]	validation_0-rmse:9.74780	validation_1-rmse:10.27426
# [21]	validation_0-rmse:9.73046	validation_1-rmse:10.29971
# [22]	validation_0-rmse:9.72914	validation_1-rmse:10.29971
# [23]	validation_0-rmse:9.69954	validation_1-rmse:10.31451
# [24]	validation_0-rmse:9.69328	validation_1-rmse:10.31004
# [25]	validation_0-rmse:9.69240	validation_1-rmse:10.31004
# [26]	validation_0-rmse:9.68692	validation_1-rmse:10.31747
# [27]	validation_0-rmse:9.61903	validation_1-rmse:10.29733
# [28]	validation_0-rmse:9.61757	validation_1-rmse:10.29648
# [29]	validation_0-rmse:9.61626	validation_1-rmse:10.30554
# [30]	validation_0-rmse:9.61197	validation_1-rmse:10.30584
# [31]	validation_0-rmse:9.60658	validation_1-rmse:10.30102
# [32]	validation_0-rmse:9.59425	validation_1-rmse:10.29079
# [33]	validation_0-rmse:9.57193	validation_1-rmse:10.29935
# [34]	validation_0-rmse:9.55857	validation_1-rmse:10.29251
# [35]	validation_0-rmse:9.55811	validation_1-rmse:10.29251
# [36]	validation_0-rmse:9.55022	validation_1-rmse:10.34272
# [37]	validation_0-rmse:9.54985	validation_1-rmse:10.34628
# [38]	validation_0-rmse:9.54952	validation_1-rmse:10.34830
# [39]	validation_0-rmse:9.53680	validation_1-rmse:10.34324
# [40]	validation_0-rmse:9.52512	validation_1-rmse:10.34441
# [41]	validation_0-rmse:9.51149	validation_1-rmse:10.32703
# [42]	validation_0-rmse:9.50075	validation_1-rmse:10.29862
# [43]	validation_0-rmse:9.48963	validation_1-rmse:10.29608
# [44]	validation_0-rmse:9.46995	validation_1-rmse:10.29129
# [45]	validation_0-rmse:9.46639	validation_1-rmse:10.28544
# [46]	validation_0-rmse:9.46612	validation_1-rmse:10.28544
# [47]	validation_0-rmse:9.46087	validation_1-rmse:10.27912
# [48]	validation_0-rmse:9.45435	validation_1-rmse:10.32657
# [49]	validation_0-rmse:9.45371	validation_1-rmse:10.32750
# [50]	validation_0-rmse:9.44097	validation_1-rmse:10.33143
# [51]	validation_0-rmse:9.41150	validation_1-rmse:10.33420
# [52]	validation_0-rmse:9.40888	validation_1-rmse:10.33421
# [53]	validation_0-rmse:9.40305	validation_1-rmse:10.33086
# [54]	validation_0-rmse:9.40089	validation_1-rmse:10.31408
# [55]	validation_0-rmse:9.38692	validation_1-rmse:10.31049
# [56]	validation_0-rmse:9.37551	validation_1-rmse:10.31121
# [57]	validation_0-rmse:9.35592	validation_1-rmse:10.30368
# [58]	validation_0-rmse:9.33630	validation_1-rmse:10.30452
# [59]	validation_0-rmse:9.32763	validation_1-rmse:10.28540
# [60]	validation_0-rmse:9.32333	validation_1-rmse:10.28284
# [61]	validation_0-rmse:9.32313	validation_1-rmse:10.28083
# [62]	validation_0-rmse:9.32298	validation_1-rmse:10.28083
# [63]	validation_0-rmse:9.30230	validation_1-rmse:10.27387
# [64]	validation_0-rmse:9.28289	validation_1-rmse:10.28003
# [65]	validation_0-rmse:9.27712	validation_1-rmse:10.27805
# [66]	validation_0-rmse:9.27541	validation_1-rmse:10.28445
# [67]	validation_0-rmse:9.27244	validation_1-rmse:10.28166
# [68]	validation_0-rmse:9.25807	validation_1-rmse:10.28218
# [69]	validation_0-rmse:9.25248	validation_1-rmse:10.27445
# [70]	validation_0-rmse:9.24365	validation_1-rmse:10.26281
# [71]	validation_0-rmse:9.23472	validation_1-rmse:10.25667
# [72]	validation_0-rmse:9.22380	validation_1-rmse:10.26614
# [73]	validation_0-rmse:9.21272	validation_1-rmse:10.27441
# [74]	validation_0-rmse:9.19666	validation_1-rmse:10.27104
# [75]	validation_0-rmse:9.17769	validation_1-rmse:10.25729
# [76]	validation_0-rmse:9.16845	validation_1-rmse:10.26283
# [77]	validation_0-rmse:9.13779	validation_1-rmse:10.26016
# [78]	validation_0-rmse:9.13150	validation_1-rmse:10.25938
# [79]	validation_0-rmse:9.12914	validation_1-rmse:10.29555
# [80]	validation_0-rmse:9.12236	validation_1-rmse:10.29424
# [81]	validation_0-rmse:9.10965	validation_1-rmse:10.29242
# [82]	validation_0-rmse:9.10953	validation_1-rmse:10.29242
# [83]	validation_0-rmse:9.09543	validation_1-rmse:10.30167
# [84]	validation_0-rmse:9.08909	validation_1-rmse:10.29381
# [85]	validation_0-rmse:9.08440	validation_1-rmse:10.29891
# [86]	validation_0-rmse:9.06956	validation_1-rmse:10.31037
# [87]	validation_0-rmse:9.06424	validation_1-rmse:10.30687
# [88]	validation_0-rmse:9.05839	validation_1-rmse:10.30895
# [89]	validation_0-rmse:9.05345	validation_1-rmse:10.30736
# [90]	validation_0-rmse:9.04542	validation_1-rmse:10.30739
# [91]	validation_0-rmse:9.03667	validation_1-rmse:10.30728
# [92]	validation_0-rmse:9.02872	validation_1-rmse:10.30939
# [93]	validation_0-rmse:9.01934	validation_1-rmse:10.31531
# [94]	validation_0-rmse:9.01893	validation_1-rmse:10.31411
# [95]	validation_0-rmse:9.01828	validation_1-rmse:10.31761
# [96]	validation_0-rmse:9.01283	validation_1-rmse:10.29798
# [97]	validation_0-rmse:9.00767	validation_1-rmse:10.30151
# [98]	validation_0-rmse:9.00273	validation_1-rmse:10.30674
# [99]	validation_0-rmse:8.99783	validation_1-rmse:10.26376
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# ### Feature importance

# %%
fig, ax = plt.subplots(figsize = (10, 10))
xgb.plot_importance(model, importance_type = "gain", ax = ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>
