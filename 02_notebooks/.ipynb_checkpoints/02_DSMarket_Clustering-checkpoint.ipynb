# %% [markdown]
# # DSMarket - Clustering

# %% [markdown]
# ### 1. Instalacion de paquetes

# %%
# !pip install seaborn
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from seaborn) (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn) (2.3.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\otalv\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn) (3.6.0)

# %% [markdown]
# ## 2. Importacion de librerias

# %%
# silence warnings
import warnings
warnings.filterwarnings("ignore")

# operating system
import os

# time calculation to track some processes
import time

# numeric and matrix operations
import numpy as np
import pandas as pd

# loading ploting libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# python core library for machine learning and data science
import sklearn
from sklearn import set_config
set_config(transform_output = "pandas")

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler
from sklearn.impute import KNNImputer, SimpleImputer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# ## 3. Carga de datos

# %%
df = pd.read_parquet("df_sales_week.parquet", engine="pyarrow")
print(df.shape)
df.head(3)
# Out:
# (8354260, 12)
#                        id              item    category    department  \
# 0  ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 1  ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
# 2  ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1
#
#        store store_code  region  yearweek  n_sales  revenue  avg_sell_price  \
# 0  South_End      BOS_1  Boston    201105        0      0.0         12.7414
# 1  South_End      BOS_1  Boston    201106        0      0.0         12.7414
# 2  South_End      BOS_1  Boston    201107        0      0.0         12.7414
#
#              event
# 0    Without event
# 1        SuperBowl
# 2  Valentine's Day

# %% [markdown]
# ## 4. Exploratory Data Analysis (EDA)

# %%
def report_df(df, verbose = True):
    '''
    Hace un report simple sobre el DataFrame suministrado.
    '''
    print(df.info(verbose = verbose))
    total_nulos = df.isnull().sum().sum()
    print()
    print(f"Tenemos un total de {total_nulos} nulos")

def unique_counts(df: pd.DataFrame) -> pd.DataFrame:
    """
    Retorna un DataFrame con la cantidad de valores únicos por columna.
    
    Parámetros:
        df (pd.DataFrame): DataFrame de entrada
    
    Retorna:
        pd.DataFrame: columnas y cantidad de valores únicos
    """
    result = pd.DataFrame({
        "columna": df.columns,
        "valores_unicos": [df[col].nunique(dropna=False) for col in df.columns]
    })
    return result

# %%
report_df(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8354260 entries, 0 to 8354259
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              object
#  1   item            object
#  2   category        object
#  3   department      object
#  4   store           object
#  5   store_code      object
#  6   region          object
#  7   yearweek        int64
#  8   n_sales         int64
#  9   revenue         float64
#  10  avg_sell_price  float64
#  11  event           object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 764.9+ MB
# None
#
# Tenemos un total de 0 nulos

# %%
unique_counts(df)
# Out:
#            columna  valores_unicos
# 0               id           30490
# 1             item            3049
# 2         category               3
# 3       department               7
# 4            store              10
# 5       store_code              10
# 6           region               3
# 7         yearweek             274
# 8          n_sales            1099
# 9          revenue           50724
# 10  avg_sell_price            2945
# 11           event              16

# %%
# Asignar 'id' como índice
df = df.set_index("id", drop=True)

# %%
df.head(3)
# Out:
#                                     item    category    department      store  \
# id
# ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End
# ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End
# ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End
#
#                        store_code  region  yearweek  n_sales  revenue  \
# id
# ACCESORIES_1_001_BOS_1      BOS_1  Boston    201105        0      0.0
# ACCESORIES_1_001_BOS_1      BOS_1  Boston    201106        0      0.0
# ACCESORIES_1_001_BOS_1      BOS_1  Boston    201107        0      0.0
#
#                         avg_sell_price            event
# id
# ACCESORIES_1_001_BOS_1         12.7414    Without event
# ACCESORIES_1_001_BOS_1         12.7414        SuperBowl
# ACCESORIES_1_001_BOS_1         12.7414  Valentine's Day

# %% [markdown]
# ## 5. Clustering productos

# %% [markdown]
# ### 5.1. Agrupar ventas por producto-semana

# %%
df_items = (
    df.groupby(["item", "category", "department", "yearweek", "event"], as_index=False)
    .agg(
        n_sales=("n_sales", "sum"),
        revenue=("revenue", "sum"),
        avg_sell_price=("avg_sell_price", "mean"),
    )
)

# %%
df_items
# Out:
#                      item     category     department  yearweek  \
# 0        ACCESORIES_1_001   ACCESORIES   ACCESORIES_1    201105
# 1        ACCESORIES_1_001   ACCESORIES   ACCESORIES_1    201106
# 2        ACCESORIES_1_001   ACCESORIES   ACCESORIES_1    201107
# 3        ACCESORIES_1_001   ACCESORIES   ACCESORIES_1    201108
# 4        ACCESORIES_1_001   ACCESORIES   ACCESORIES_1    201109
# ...                   ...          ...            ...       ...
# 835421  SUPERMARKET_3_827  SUPERMARKET  SUPERMARKET_3    201613
# 835422  SUPERMARKET_3_827  SUPERMARKET  SUPERMARKET_3    201614
# 835423  SUPERMARKET_3_827  SUPERMARKET  SUPERMARKET_3    201615
# 835424  SUPERMARKET_3_827  SUPERMARKET  SUPERMARKET_3    201616
# 835425  SUPERMARKET_3_827  SUPERMARKET  SUPERMARKET_3    201617
#
#                   event  n_sales  revenue  avg_sell_price
# 0         Without event        0      0.0        11.95936
# 1             SuperBowl        0      0.0        11.95936
# 2       Valentine's Day        0      0.0        11.95936
# 3         Without event        0      0.0        11.95936
# 4         Without event        0      0.0        11.95936
# ...                 ...      ...      ...             ...
# 835421           Easter      167    200.4         1.20000
# 835422    Without event      205    246.0         1.20000
# 835423    Without event      167    200.4         1.20000
# 835424    Without event      186    223.2         1.20000
# 835425    Without event       60     72.0         1.20000
#
# [835426 rows x 8 columns]

# %% [markdown]
# ### 5.2. Agregar features

# %%
# Features básicos por item
features_item = (
    df_items.groupby("item")
    .agg(
        mean_sales=("n_sales", "mean"),
        std_sales=("n_sales", "std"),
        max_sales=("n_sales", "max"),
        min_sales=("n_sales", "min"),
        mean_revenue=("revenue", "mean"),
        std_revenue=("revenue", "std"),
        total_sales=("n_sales", "sum"),
        total_revenue=("revenue", "sum"),
        avg_price=("avg_sell_price", "mean"),
    )
    .reset_index()
)

# Coeficiente de variación
# features_item["cv_sales"] = features_item["std_sales"] / features_item["mean_sales"].replace(0, np.nan)
features_item["cv_revenue"] = features_item["std_revenue"] / features_item["mean_revenue"].replace(0, np.nan)

# % semanas con 0 ventas
pct_zero = (
    df_items.groupby("item")["n_sales"]
    .apply(lambda x: (x == 0).mean())
    .reset_index(name="pct_weeks_zero")
)

# % de ventas en semanas con evento
sales_event = (
    df_items.groupby(["item", "event"])["n_sales"].sum().reset_index()
)

sales_event_flag = (
    sales_event.groupby("item")
    .apply(lambda x: x.loc[x["event"] != "Without event", "n_sales"].sum() / x["n_sales"].sum())
    .reset_index(name="pct_sales_event")
)

# Unir todo
features_item = (
    features_item
    .merge(pct_zero, on="item", how="left")
    .merge(sales_event_flag, on="item", how="left")
    .fillna({"pct_sales_event": 0})
)

# %%
features_item.head(3)
# Out:
#                item  mean_sales  std_sales  max_sales  min_sales  \
# 0  ACCESORIES_1_001   14.937956  15.317871         58          0
# 1  ACCESORIES_1_002   18.463504  10.965837        102          0
# 2  ACCESORIES_1_003    5.237226   7.646872         37          0
#
#    mean_revenue  std_revenue  total_sales  total_revenue  avg_price  \
# 0    164.371399   168.393424         4093     45037.7634  11.467561
# 1     97.474729    57.902918         5059     26708.0758   5.276746
# 2     20.643590    30.192925         1435      5656.3437   3.947629
#
#    cv_revenue  pct_weeks_zero  pct_sales_event
# 0    1.024469        0.467153         0.298803
# 1    0.594030        0.062044         0.320617
# 2    1.462581        0.591241         0.340070

# %% [markdown]
# ### 5.3. Establecer numero de clusters

# %%
# Selección dinámica solo de variables numéricas
X = (
    features_item
    .select_dtypes(include=[np.number])   # solo numéricas
    .replace([np.inf, -np.inf], np.nan)   # manejar infinitos
    .fillna(0.0)                          # manejar nulos
)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
sse = {}
for k in range(2, 15):   # probamos de 2 a 14 clusters
    kmeans = KMeans(n_clusters=k, random_state=42, n_init="auto")
    kmeans.fit(X_scaled)
    sse[k] = kmeans.inertia_

# %%
fig = plt.figure(figsize=(8, 4))
ax = fig.add_subplot()

x_values = list(sse.keys())
y_values = list(sse.values())

ax.plot(x_values, y_values, marker="o", label="Inercia (SSE)")
ax.set_xlabel("Número de clusters (k)", fontsize=12)
ax.set_ylabel("Inercia (SSE)", fontsize=12)
ax.legend()
fig.suptitle("Método del Codo (Elbow Method)", fontsize=16)
plt.show()

# %% [markdown]
# ### 5.4. Creacion de pipeline

# %%
# Definir pipeline
pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("kmeans", KMeans(n_clusters=4, random_state=175, n_init="auto"))
])

# Entrenar modelo
pipeline.fit(X)

# Obtener etiquetas de cluster
features_item["cluster"] = pipeline["kmeans"].labels_

# %%
# Distribución por cluster
print(features_item["cluster"].value_counts())
# Out:
# cluster
# 3    1787
# 0     955
# 1     285
# 2      22
# Name: count, dtype: int64

# %%
features_item.head(3)
# Out:
#                item  mean_sales  std_sales  max_sales  min_sales  \
# 0  ACCESORIES_1_001   14.937956  15.317871         58          0
# 1  ACCESORIES_1_002   18.463504  10.965837        102          0
# 2  ACCESORIES_1_003    5.237226   7.646872         37          0
#
#    mean_revenue  std_revenue  total_sales  total_revenue  avg_price  \
# 0    164.371399   168.393424         4093     45037.7634  11.467561
# 1     97.474729    57.902918         5059     26708.0758   5.276746
# 2     20.643590    30.192925         1435      5656.3437   3.947629
#
#    cv_revenue  pct_weeks_zero  pct_sales_event  cluster
# 0    1.024469        0.467153         0.298803        0
# 1    0.594030        0.062044         0.320617        3
# 2    1.462581        0.591241         0.340070        0

# %%
# Tomar las columnas categóricas únicas por item
df_cats = df_items[["item", "category", "department"]].drop_duplicates("item")

# Unirlas con tus features agregados
features_item = features_item.merge(df_cats, on="item", how="left")

# %%
df_items.shape
# Out:
# (835426, 8)

# %%
features_item.head(3)
# Out:
#                item  mean_sales  std_sales  max_sales  min_sales  \
# 0  ACCESORIES_1_001   14.937956  15.317871         58          0
# 1  ACCESORIES_1_002   18.463504  10.965837        102          0
# 2  ACCESORIES_1_003    5.237226   7.646872         37          0
#
#    mean_revenue  std_revenue  total_sales  total_revenue  avg_price  \
# 0    164.371399   168.393424         4093     45037.7634  11.467561
# 1     97.474729    57.902918         5059     26708.0758   5.276746
# 2     20.643590    30.192925         1435      5656.3437   3.947629
#
#    cv_revenue  pct_weeks_zero  pct_sales_event  cluster    category  \
# 0    1.024469        0.467153         0.298803        0  ACCESORIES
# 1    0.594030        0.062044         0.320617        3  ACCESORIES
# 2    1.462581        0.591241         0.340070        0  ACCESORIES
#
#      department
# 0  ACCESORIES_1
# 1  ACCESORIES_1
# 2  ACCESORIES_1

# %%
features_item.to_csv("clustering_data.csv", index=False, encoding="utf-8")

# %%
pipeline["kmeans"].labels_.shape
# Out:
# (3049,)

# %%
pipeline[:2]
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('kmeans', KMeans(n_clusters=4, random_state=175))])

# %%
features_item["cluster"] = pipeline["kmeans"].labels_

# %%
features_item.head(3)
# Out:
#                item  mean_sales  std_sales  max_sales  min_sales  \
# 0  ACCESORIES_1_001   14.937956  15.317871         58          0
# 1  ACCESORIES_1_002   18.463504  10.965837        102          0
# 2  ACCESORIES_1_003    5.237226   7.646872         37          0
#
#    mean_revenue  std_revenue  total_sales  total_revenue  avg_price  \
# 0    164.371399   168.393424         4093     45037.7634  11.467561
# 1     97.474729    57.902918         5059     26708.0758   5.276746
# 2     20.643590    30.192925         1435      5656.3437   3.947629
#
#    cv_revenue  pct_weeks_zero  pct_sales_event  cluster    category  \
# 0    1.024469        0.467153         0.298803        0  ACCESORIES
# 1    0.594030        0.062044         0.320617        3  ACCESORIES
# 2    1.462581        0.591241         0.340070        0  ACCESORIES
#
#      department
# 0  ACCESORIES_1
# 1  ACCESORIES_1
# 2  ACCESORIES_1

# %% [markdown]
# ### 5.5. Verificacion de clusters por feature

# %%
(
    features_item
    .groupby(["cluster"])
    .describe()
    .T
    .style
    .format('{:.2f}')
    .background_gradient(cmap = 'Blues', axis = 1)
)
# Out:
# <style type="text/css">
# #T_26ac4_row0_col0, #T_26ac4_row8_col0, #T_26ac4_row16_col0, #T_26ac4_row24_col0, #T_26ac4_row32_col0, #T_26ac4_row40_col0, #T_26ac4_row48_col0, #T_26ac4_row56_col0, #T_26ac4_row64_col0, #T_26ac4_row72_col0, #T_26ac4_row80_col0, #T_26ac4_row88_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_26ac4_row0_col1, #T_26ac4_row8_col1, #T_26ac4_row16_col1, #T_26ac4_row24_col1, #T_26ac4_row25_col1, #T_26ac4_row32_col1, #T_26ac4_row40_col1, #T_26ac4_row48_col1, #T_26ac4_row56_col1, #T_26ac4_row64_col1, #T_26ac4_row72_col1, #T_26ac4_row80_col1, #T_26ac4_row88_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_26ac4_row0_col2, #T_26ac4_row1_col0, #T_26ac4_row2_col0, #T_26ac4_row3_col0, #T_26ac4_row3_col3, #T_26ac4_row4_col0, #T_26ac4_row5_col0, #T_26ac4_row6_col0, #T_26ac4_row7_col0, #T_26ac4_row8_col2, #T_26ac4_row9_col3, #T_26ac4_row10_col3, #T_26ac4_row11_col3, #T_26ac4_row12_col3, #T_26ac4_row13_col0, #T_26ac4_row13_col3, #T_26ac4_row14_col3, #T_26ac4_row15_col3, #T_26ac4_row16_col2, #T_26ac4_row17_col0, #T_26ac4_row18_col0, #T_26ac4_row18_col3, #T_26ac4_row19_col3, #T_26ac4_row20_col0, #T_26ac4_row20_col3, #T_26ac4_row21_col0, #T_26ac4_row22_col0, #T_26ac4_row23_col0, #T_26ac4_row23_col3, #T_26ac4_row24_col2, #T_26ac4_row25_col0, #T_26ac4_row26_col0, #T_26ac4_row27_col0, #T_26ac4_row27_col1, #T_26ac4_row27_col2, #T_26ac4_row27_col3, #T_26ac4_row28_col0, #T_26ac4_row28_col1, #T_26ac4_row28_col2, #T_26ac4_row28_col3, #T_26ac4_row29_col0, #T_26ac4_row29_col1, #T_26ac4_row29_col2, #T_26ac4_row29_col3, #T_26ac4_row30_col0, #T_26ac4_row31_col0, #T_26ac4_row32_col2, #T_26ac4_row33_col0, #T_26ac4_row34_col0, #T_26ac4_row35_col0, #T_26ac4_row35_col3, #T_26ac4_row36_col0, #T_26ac4_row37_col0, #T_26ac4_row38_col0, #T_26ac4_row39_col0, #T_26ac4_row40_col2, #T_26ac4_row41_col3, #T_26ac4_row42_col3, #T_26ac4_row43_col0, #T_26ac4_row44_col3, #T_26ac4_row45_col3, #T_26ac4_row46_col3, #T_26ac4_row47_col3, #T_26ac4_row48_col2, #T_26ac4_row49_col0, #T_26ac4_row50_col0, #T_26ac4_row51_col0, #T_26ac4_row51_col3, #T_26ac4_row52_col0, #T_26ac4_row53_col0, #T_26ac4_row54_col0, #T_26ac4_row55_col0, #T_26ac4_row56_col2, #T_26ac4_row57_col0, #T_26ac4_row58_col0, #T_26ac4_row59_col0, #T_26ac4_row59_col3, #T_26ac4_row60_col0, #T_26ac4_row61_col0, #T_26ac4_row62_col0, #T_26ac4_row63_col0, #T_26ac4_row64_col2, #T_26ac4_row65_col2, #T_26ac4_row66_col3, #T_26ac4_row67_col1, #T_26ac4_row68_col1, #T_26ac4_row69_col2, #T_26ac4_row70_col2, #T_26ac4_row71_col1, #T_26ac4_row72_col2, #T_26ac4_row73_col3, #T_26ac4_row74_col3, #T_26ac4_row75_col2, #T_26ac4_row76_col2, #T_26ac4_row77_col3, #T_26ac4_row78_col3, #T_26ac4_row79_col3, #T_26ac4_row80_col2, #T_26ac4_row81_col3, #T_26ac4_row82_col3, #T_26ac4_row83_col1, #T_26ac4_row83_col2, #T_26ac4_row83_col3, #T_26ac4_row84_col1, #T_26ac4_row84_col2, #T_26ac4_row84_col3, #T_26ac4_row85_col2, #T_26ac4_row86_col3, #T_26ac4_row87_col3, #T_26ac4_row88_col2, #T_26ac4_row89_col3, #T_26ac4_row90_col3, #T_26ac4_row91_col0, #T_26ac4_row92_col0, #T_26ac4_row93_col0, #T_26ac4_row94_col3, #T_26ac4_row95_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_26ac4_row0_col3, #T_26ac4_row1_col2, #T_26ac4_row2_col2, #T_26ac4_row3_col2, #T_26ac4_row4_col2, #T_26ac4_row5_col2, #T_26ac4_row6_col2, #T_26ac4_row7_col2, #T_26ac4_row8_col3, #T_26ac4_row9_col2, #T_26ac4_row10_col2, #T_26ac4_row11_col2, #T_26ac4_row12_col2, #T_26ac4_row13_col2, #T_26ac4_row14_col2, #T_26ac4_row15_col2, #T_26ac4_row16_col3, #T_26ac4_row17_col2, #T_26ac4_row18_col2, #T_26ac4_row19_col2, #T_26ac4_row20_col2, #T_26ac4_row21_col2, #T_26ac4_row22_col2, #T_26ac4_row23_col2, #T_26ac4_row24_col3, #T_26ac4_row25_col2, #T_26ac4_row26_col2, #T_26ac4_row30_col2, #T_26ac4_row31_col2, #T_26ac4_row32_col3, #T_26ac4_row33_col2, #T_26ac4_row34_col2, #T_26ac4_row35_col2, #T_26ac4_row36_col2, #T_26ac4_row37_col2, #T_26ac4_row38_col2, #T_26ac4_row39_col2, #T_26ac4_row40_col3, #T_26ac4_row41_col2, #T_26ac4_row42_col2, #T_26ac4_row43_col2, #T_26ac4_row44_col2, #T_26ac4_row45_col2, #T_26ac4_row46_col2, #T_26ac4_row47_col2, #T_26ac4_row48_col3, #T_26ac4_row49_col2, #T_26ac4_row50_col2, #T_26ac4_row51_col2, #T_26ac4_row52_col2, #T_26ac4_row53_col2, #T_26ac4_row54_col2, #T_26ac4_row55_col2, #T_26ac4_row56_col3, #T_26ac4_row57_col2, #T_26ac4_row58_col2, #T_26ac4_row59_col2, #T_26ac4_row60_col2, #T_26ac4_row61_col2, #T_26ac4_row62_col2, #T_26ac4_row63_col2, #T_26ac4_row64_col3, #T_26ac4_row65_col0, #T_26ac4_row66_col2, #T_26ac4_row67_col2, #T_26ac4_row68_col3, #T_26ac4_row69_col3, #T_26ac4_row70_col3, #T_26ac4_row71_col3, #T_26ac4_row72_col3, #T_26ac4_row73_col0, #T_26ac4_row74_col2, #T_26ac4_row75_col0, #T_26ac4_row76_col0, #T_26ac4_row77_col0, #T_26ac4_row78_col0, #T_26ac4_row79_col0, #T_26ac4_row80_col3, #T_26ac4_row81_col0, #T_26ac4_row82_col2, #T_26ac4_row83_col0, #T_26ac4_row84_col0, #T_26ac4_row85_col0, #T_26ac4_row86_col0, #T_26ac4_row87_col0, #T_26ac4_row88_col3, #T_26ac4_row89_col1, #T_26ac4_row90_col1, #T_26ac4_row91_col2, #T_26ac4_row92_col2, #T_26ac4_row93_col2, #T_26ac4_row94_col0, #T_26ac4_row95_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_26ac4_row1_col1, #T_26ac4_row12_col1, #T_26ac4_row13_col1, #T_26ac4_row20_col1, #T_26ac4_row21_col1, #T_26ac4_row49_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_26ac4_row1_col3, #T_26ac4_row2_col3, #T_26ac4_row5_col3, #T_26ac4_row49_col3, #T_26ac4_row50_col3, #T_26ac4_row53_col3 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_26ac4_row2_col1, #T_26ac4_row4_col1, #T_26ac4_row50_col1, #T_26ac4_row52_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_26ac4_row3_col1, #T_26ac4_row51_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_26ac4_row4_col3, #T_26ac4_row41_col0, #T_26ac4_row52_col3 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_26ac4_row5_col1, #T_26ac4_row53_col1, #T_26ac4_row76_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_26ac4_row6_col1, #T_26ac4_row54_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_26ac4_row6_col3, #T_26ac4_row42_col0, #T_26ac4_row54_col3, #T_26ac4_row85_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_26ac4_row7_col1, #T_26ac4_row55_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_26ac4_row7_col3, #T_26ac4_row26_col3, #T_26ac4_row36_col3, #T_26ac4_row55_col3, #T_26ac4_row60_col3, #T_26ac4_row75_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_26ac4_row9_col0, #T_26ac4_row10_col0, #T_26ac4_row11_col0, #T_26ac4_row12_col0, #T_26ac4_row14_col0, #T_26ac4_row17_col3, #T_26ac4_row21_col3, #T_26ac4_row30_col3, #T_26ac4_row43_col3, #T_26ac4_row44_col0, #T_26ac4_row75_col1, #T_26ac4_row85_col3, #T_26ac4_row93_col3 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_26ac4_row9_col1, #T_26ac4_row42_col1 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_26ac4_row10_col1, #T_26ac4_row26_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_26ac4_row11_col1, #T_26ac4_row39_col3, #T_26ac4_row63_col3, #T_26ac4_row73_col1, #T_26ac4_row78_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_26ac4_row14_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_26ac4_row15_col0, #T_26ac4_row19_col0, #T_26ac4_row45_col0, #T_26ac4_row46_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_26ac4_row15_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_26ac4_row17_col1 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_26ac4_row18_col1, #T_26ac4_row19_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_26ac4_row22_col1 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_26ac4_row22_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_26ac4_row23_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_26ac4_row25_col3, #T_26ac4_row30_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_26ac4_row31_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_26ac4_row31_col3 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_26ac4_row33_col1, #T_26ac4_row34

# %% [markdown]
# ## 6. Ficha de productos

# %%
ficha_df = pd.DataFrame()

# %%
for i, col in enumerate(["pct_weeks_zero", "total_sales", "pct_sales_event", "avg_price"]):
    resumen_data = features_item[["cluster", col]].groupby("cluster").describe().T[1:]
    ficha_df = pd.concat([ficha_df, resumen_data])

# %%
ficha_df
# Out:
# cluster                          0              1             2             3
# pct_weeks_zero  mean      0.514744       0.111000  1.368613e-01      0.083286
#                 std       0.133191       0.134874  2.040216e-01      0.093498
#                 min       0.131387       0.000000  0.000000e+00      0.000000
#                 25%       0.405109       0.000000  0.000000e+00      0.000000
#                 50%       0.500000       0.054745  4.197080e-02      0.043796
#                 75%       0.614964       0.193431  1.788321e-01      0.149635
#                 max       0.843066       0.594891  6.715328e-01      0.368613
# total_sales     mean   7025.112042   84891.315789  3.505252e+05  15154.363179
#                 std    7094.027611   49405.191039  2.308117e+05  13172.242012
#                 min     568.000000   11716.000000  2.932000e+04    660.000000
#                 25%    2450.500000   51553.000000  2.611110e+05   5849.500000
#                 50%    4590.000000   74406.000000  2.826190e+05  11175.000000
#                 75%    8863.500000  109692.000000  3.945895e+05  20540.500000
#                 max   54616.000000  257119.000000  1.002529e+06  90433.000000
# pct_sales_event mean      0.290812       0.295287  2.950364e-01      0.290120
#                 std       0.023477       0.025409  1.643430e-02      0.015829
#                 min       0.204729       0.249289  2.600761e-01      0.223824
#                 25%       0.277220       0.284252  2.871266e-01      0.281583
#                 50%       0.289794       0.292022  2.972856e-01      0.289825
#                 75%       0.303062       0.301647  3.015886e-01      0.298275
#                 max       0.419637       0.523210  3.328798e-01      0.418196
# avg_price       mean      5.801029       4.658864  3.886430e+00      5.600374
#                 std       4.940629       4.936019  6.218438e+00      4.184768
#                 min       0.305900       0.239668  1.175632e+00      0.305900
#                 25%       2.754201       1.274825  1.688126e+00      2.945975
#                 50%       3.950100       2.993676  1.912139e+00      4.547208
#                 75%       7.219690       5.573440  3.015388e+00      7.300000
#                 max      37.599100      28.696633  3.068060e+01     39.444270

# %%
# generamos nuestro multiindex
out_index = [
    "Ventas",
    "Rotacion",
    "Estacionalidad",
    "Costo"
]

inner_index = [
    "pct_weeks_zero", "total_sales", "pct_sales_event", "avg_price"
]

estadisticos = ["Media", "Desviación", "Mínimo", "Perc. 25", "Perc. 50", "Perc. 75", "Máximo"]

new_multi_index = []

for oi, ii, in zip(out_index, inner_index):
    for es in estadisticos:
        new_multi_index.append((oi, ii, es))

# %%
def generate_multiindex(list_of_tuples, names):
    return pd.MultiIndex.from_tuples(list_of_tuples, names = names)

# %%
names = ["Grupo Indicadores", "Indicador", "Estadístico"]
index_ficha = generate_multiindex(new_multi_index, names)
ficha_df.set_index(index_ficha, inplace = True)

# %%
tamaño_clusters = features_item.groupby("cluster").size().to_frame().T
tamaño_clusters.set_index(generate_multiindex([("General", "Clúster", "Tamaño")] , names), inplace = True)

# %%
ficha_df = pd.concat([tamaño_clusters, ficha_df])

# %%
ficha_df
# Out:
# cluster                                                   0              1  \
# Grupo Indicadores Indicador       Estadístico
# General           Clúster         Tamaño         955.000000     285.000000
# Ventas            pct_weeks_zero  Media            0.514744       0.111000
#                                   Desviación       0.133191       0.134874
#                                   Mínimo           0.131387       0.000000
#                                   Perc. 25         0.405109       0.000000
#                                   Perc. 50         0.500000       0.054745
#                                   Perc. 75         0.614964       0.193431
#                                   Máximo           0.843066       0.594891
# Rotacion          total_sales     Media         7025.112042   84891.315789
#                                   Desviación    7094.027611   49405.191039
#                                   Mínimo         568.000000   11716.000000
#                                   Perc. 25      2450.500000   51553.000000
#                                   Perc. 50      4590.000000   74406.000000
#                                   Perc. 75      8863.500000  109692.000000
#                                   Máximo       54616.000000  257119.000000
# Estacionalidad    pct_sales_event Media            0.290812       0.295287
#                                   Desviación       0.023477       0.025409
#                                   Mínimo           0.204729       0.249289
#                                   Perc. 25         0.277220       0.284252
#                                   Perc. 50         0.289794       0.292022
#                                   Perc. 75         0.303062       0.301647
#                                   Máximo           0.419637       0.523210
# Costo             avg_price       Media            5.801029       4.658864
#                                   Desviación       4.940629       4.936019
#                                   Mínimo           0.305900       0.239668
#                                   Perc. 25         2.754201       1.274825
#                                   Perc. 50         3.950100       2.993676
#                                   Perc. 75         7.219690       5.573440
#                                   Máximo          37.599100      28.696633
#
# cluster                                                   2             3
# Grupo Indicadores Indicador       Estadístico
# General           Clúster         Tamaño       2.200000e+01   1787.000000
# Ventas            pct_weeks_zero  Media        1.368613e-01      0.083286
#                                   Desviación   2.040216e-01      0.093498
#                                   Mínimo       0.000000e+00      0.000000
#                                   Perc. 25     0.000000e+00      0.000000
#                                   Perc. 50     4.197080e-02      0.043796
#                                   Perc. 75     1.788321e-01      0.149635
#                                   Máximo       6.715328e-01      0.368613
# Rotacion          total_sales     Media        3.505252e+05  15154.363179
#                                   Desviación   2.308117e+05  13172.242012
#                                   Mínimo       2.932000e+04    660.000000
#                                   Perc. 25     2.611110e+05   5849.500000
#                                   Perc. 50     2.826190e+05  11175.000000
#                                   Perc. 75     3.945895e+05  20540.500000
#                                   Máximo       1.002529e+06  90433.000000
# Estacionalidad    pct_sales_event Media        2.950364e-01      0.290120
#                                   Desviación   1.643430e-02      0.015829
#                                   Mínimo       2.600761e-01      0.223824
#                                   Perc. 25     2.871266e-01      0.281583
#                                   Perc. 50     2.972856e-01      0.289825
#                                   Perc. 75     3.015886e-01      0.298275
#                                   Máximo       3.328798e-01      0.418196
# Costo             avg_price       Media        3.886430e+00      5.600374
#                                   Desviación   6.218438e+00      4.184768
#                                   Mínimo       1.175632e+00      0.305900
#                                   Perc. 25     1.688126e+00      2.945975
#                                   Perc. 50     1.912139e+00      4.547208
#                                   Perc. 75     3.015388e+00      7.300000
#                                   Máximo       3.068060e+01     39.444270

# %%
float_format = '{:.2f}'

# %%
(
    ficha_df
    .rename(columns = {
        0 : "Menor Rotacion",
        1 : "Eventos",
        2 : "Top Ventas",
        3 : "Alto valor"
    })
    .style
    .format(float_format)
    .background_gradient(cmap = 'Blues', axis = 1)
)
# Out:
# <style type="text/css">
# #T_e1834_row0_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_e1834_row0_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_e1834_row0_col2, #T_e1834_row1_col3, #T_e1834_row2_col3, #T_e1834_row3_col1, #T_e1834_row3_col2, #T_e1834_row3_col3, #T_e1834_row4_col1, #T_e1834_row4_col2, #T_e1834_row4_col3, #T_e1834_row5_col2, #T_e1834_row6_col3, #T_e1834_row7_col3, #T_e1834_row8_col0, #T_e1834_row9_col0, #T_e1834_row10_col0, #T_e1834_row10_col3, #T_e1834_row11_col0, #T_e1834_row12_col0, #T_e1834_row13_col0, #T_e1834_row14_col0, #T_e1834_row15_col3, #T_e1834_row16_col3, #T_e1834_row17_col0, #T_e1834_row18_col0, #T_e1834_row19_col0, #T_e1834_row20_col3, #T_e1834_row21_col2, #T_e1834_row22_col2, #T_e1834_row23_col3, #T_e1834_row24_col1, #T_e1834_row25_col1, #T_e1834_row26_col2, #T_e1834_row27_col2, #T_e1834_row28_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e1834_row0_col3, #T_e1834_row1_col0, #T_e1834_row2_col2, #T_e1834_row3_col0, #T_e1834_row4_col0, #T_e1834_row5_col0, #T_e1834_row6_col0, #T_e1834_row7_col0, #T_e1834_row8_col2, #T_e1834_row9_col2, #T_e1834_row10_col2, #T_e1834_row11_col2, #T_e1834_row12_col2, #T_e1834_row13_col2, #T_e1834_row14_col2, #T_e1834_row15_col1, #T_e1834_row16_col1, #T_e1834_row17_col2, #T_e1834_row18_col2, #T_e1834_row19_col2, #T_e1834_row20_col0, #T_e1834_row21_col1, #T_e1834_row22_col0, #T_e1834_row23_col2, #T_e1834_row24_col2, #T_e1834_row25_col3, #T_e1834_row26_col3, #T_e1834_row27_col3, #T_e1834_row28_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e1834_row1_col1, #T_e1834_row6_col2, #T_e1834_row16_col2 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_e1834_row1_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_e1834_row2_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_e1834_row2_col1, #T_e1834_row23_col0 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_e1834_row5_col1, #T_e1834_row13_col3 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_e1834_row5_col3, #T_e1834_row19_col3 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_e1834_row6_col1 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_e1834_row7_col1 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_e1834_row7_col2 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_e1834_row8_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_e1834_row8_col3, #T_e1834_row9_col3, #T_e1834_row12_col3 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_e1834_row9_col1, #T_e1834_row11_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_e1834_row10_col1 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_e1834_row11_col3 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_e1834_row12_col1 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_e1834_row13_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_e1834_row14_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_e1834_row14_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_e1834_row15_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_e1834_row15_col2 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_e1834_row16_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_e1834_row17_col1 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_e1834_row17_col3 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_e1834_row18_col1 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_e1834_row18_col3 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_e1834_row19_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_e1834_row20_col1 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_e1834_row20_col2 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_e1834_row21_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_e1834_row21_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_e1834_row22_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_e1834_row22_col3 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_e1834_row23_col1 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_e1834_row24_col0, #T_e1834_row24_col3 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_e1834_row25_col0 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_e1834_row25_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_e1834_row26_col0 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_e1834_row26_col1 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_e1834_row27_col0 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_e1834_row27_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_e1834_row28_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_e1834_row28_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# </style>
# <table id="T_e1834">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >cluster</th>
#       <th id="T_e1834_level0_col0" class="col_heading level0 col0" >Menor Rotacion</th>
#       <th id="T_e1834_level0_col1" class="col_heading level0 col1" >Eventos</th>
#       <th id="T_e1834_level0_col2" class="col_heading level0 col2" >Top Ventas</th>
#       <th id="T_e1834_level0_col3" class="col_heading level0 col3" >Alto valor</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Grupo Indicadores</th>
#       <th class="index_name level1" >Indicador</th>
#       <th class="index_name level2" >Estadístico</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1834_level0_row0" class="row_heading level0 row0" >General</th>
#       <th id="T_e1834_level1_row0" class="row_heading level1 row0" >Clúster</th>
#       <th id="T_e1834_level2_row0" class="row_heading level2 row0" >Tamaño</th>
#       <td id="T_e1834_row0_col0" class="data row0 col0" >955.00</td>
#       <td id="T_e1834_row0_col1" class="data row0 col1" >285.00</td>
#       <td id="T_e1834_row0_col2" class="data row0 col2" >22.00</td>
#       <td id="T_e1834_row0_col3" class="data row0 col3" >1787.00</td>
#     </tr>
#     <tr>
#       <th id="T_e1834_level0_row1" class="row_heading level0 row1" rowspan="7">Ventas</th>
#       <th id="T_e1834_level1_row1" class="row_heading level1 row1" rowspan="7">pct_weeks_zero</th>
#       <th id="T_e1834_level2_row1" class="row_heading level2 row1" >Media</th>
#       <td id="T_e1834_row1_col0" class="data row1 col0" >0.51</td>
#       <td id="T_e1834_row1_col1" class="data row1 col1" >0.11</td>
#       <td id="T_e1834_row1_col2" class="data row1 col2" >0.14</td>
#       <td id="T_e1834_row1_col3" class="data row1 col3" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_e1834_level2_row2" class="row_heading level2 row2" >Desviación</th>
#       <td id="T_e1834_row2_col0" class="data row2 col0" >0.13</td>
#       <td id="T_e1834_row2_col1" class="data row2 col1" >0.13</td>
#       <td id="T_e1834_row2_col2" class="data row2 col2" >0.20</td>
#       <td id="T_e1834_row2_col3" class="data row2 col3" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_e1834_level2_row3" class="row_heading level2 row3" >Mínimo</th>
#       <td id="T_e1834_row3_col0" class="data row3 col0" >0.13</td>
#       <td id="T_e1834_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_e1834_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_e1834_row3_col3" class="data row3 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e1834_level2_row4" class="row_heading level2 row4" >Perc. 25</th>
#       <td id="T_e1834_row4_col0" class="data row4 col0" >0.41</td>
#       <td id="T_e1834_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_e1834_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_e1834_row4_col3" class="data row4 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e1834_level2_row5" class="row_heading level2 row5" >Perc. 50</th>
#       <td id="T_e1834_row5_col0" class="data row5 col0" >0.50</td>
#       <td id="T_e1834_row5_c

# %% [markdown]
# ## 7. Clustering tiendas

# %%
df.head(3)
# Out:
#                                     item    category    department      store  \
# id
# ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End
# ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End
# ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End
#
#                        store_code  region  yearweek  n_sales  revenue  \
# id
# ACCESORIES_1_001_BOS_1      BOS_1  Boston    201105        0      0.0
# ACCESORIES_1_001_BOS_1      BOS_1  Boston    201106        0      0.0
# ACCESORIES_1_001_BOS_1      BOS_1  Boston    201107        0      0.0
#
#                         avg_sell_price            event
# id
# ACCESORIES_1_001_BOS_1         12.7414    Without event
# ACCESORIES_1_001_BOS_1         12.7414        SuperBowl
# ACCESORIES_1_001_BOS_1         12.7414  Valentine's Day

# %% [markdown]
# ### 7.1. Agrupar ventas por tienda-semana

# %%
df_store = (
    df.groupby(["store_code", "store", "region", "event", "yearweek"], as_index=False)
    .agg(
        n_sales=("n_sales", "sum"),
        revenue=("revenue", "sum"),
    )
)

# %%
df_store
# Out:
#      store_code          store        region          event  yearweek  \
# 0         BOS_1      South_End        Boston         Easter    201117
# 1         BOS_1      South_End        Boston         Easter    201215
# 2         BOS_1      South_End        Boston         Easter    201313
# 3         BOS_1      South_End        Boston         Easter    201416
# 4         BOS_1      South_End        Boston         Easter    201514
# ...         ...            ...           ...            ...       ...
# 2735      PHI_3  Queen_Village  Philadelphia  Without event    201612
# 2736      PHI_3  Queen_Village  Philadelphia  Without event    201614
# 2737      PHI_3  Queen_Village  Philadelphia  Without event    201615
# 2738      PHI_3  Queen_Village  Philadelphia  Without event    201616
# 2739      PHI_3  Queen_Village  Philadelphia  Without event    201617
#
#       n_sales      revenue
# 0       13303   44169.5386
# 1       22651   74461.4573
# 2       21494   71448.4021
# 3       22019   74439.3678
# 4       23324   91501.9022
# ...       ...          ...
# 2735    25035   85859.6992
# 2736    29608  103585.8488
# 2737    30192  103733.3264
# 2738    26518   92698.9460
# 2739     9011   31934.8976
#
# [2740 rows x 7 columns]

# %% [markdown]
# ### 7.2. Agregar features

# %%
# Features básicos por item
features_store = (
    df_store.groupby("store_code")
    .agg(
        mean_sales=("n_sales", "mean"),
        std_sales=("n_sales", "std"),
        max_sales=("n_sales", "max"),
        min_sales=("n_sales", "min"),
        mean_revenue=("revenue", "mean"),
        std_revenue=("revenue", "std"),
        total_sales=("n_sales", "sum"),
        total_revenue=("revenue", "sum"),
    )
    .reset_index()
)

# Coeficiente de variación
# features_item["cv_sales"] = features_item["std_sales"] / features_item["mean_sales"].replace(0, np.nan)
features_store["cv_revenue"] = features_store["std_revenue"] / features_store["mean_revenue"].replace(0, np.nan)

# % semanas con 0 ventas
pct_zero_store = (
    df_store.groupby("store_code")["n_sales"]
    .apply(lambda x: (x == 0).mean())
    .reset_index(name="pct_weeks_zero_store")
)

# % de ventas en semanas con evento
sales_event_store = (
    df_store.groupby(["store_code", "event"])["n_sales"].sum().reset_index()
)

sales_event_flag_store = (
    sales_event_store.groupby("store_code")
    .apply(lambda x: x.loc[x["event"] != "Without event", "n_sales"].sum() / x["n_sales"].sum())
    .reset_index(name="pct_sales_event_store")
)

# Unir todo
features_store = (
    features_store
    .merge(pct_zero_store, on="store_code", how="left")
    .merge(sales_event_flag_store, on="store_code", how="left")
    .fillna({"pct_sales_event_store": 0})
)

# %%
features_store.head(3)
# Out:
#   store_code    mean_sales    std_sales  max_sales  min_sales  mean_revenue  \
# 0      BOS_1  20420.773723  3398.309941      36384       3057  70589.246838
# 1      BOS_2  26329.868613  4466.445893      50154       4189  92207.065652
# 2      BOS_3  22223.832117  4242.063693      38626       3573  80088.320897
#
#     std_revenue  total_sales  total_revenue  cv_revenue  pct_weeks_zero_store  \
# 0  14002.696102      5595292   1.934145e+07    0.198369                   0.0
# 1  16372.548204      7214384   2.526474e+07    0.177563                   0.0
# 2  20657.639427      6089330   2.194420e+07    0.257936                   0.0
#
#    pct_sales_event_store
# 0               0.291544
# 1               0.291037
# 2               0.289646

# %% [markdown]
# ### 7.3. Establecer numero de clusters para tiendas

# %%
# Selección dinámica solo de variables numéricas
X = (
    features_store
    .select_dtypes(include=[np.number])   # solo numéricas
    .replace([np.inf, -np.inf], np.nan)   # manejar infinitos
    .fillna(0.0)                          # manejar nulos
)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
sse = {}
for k in range(2, 10):   # probamos de 2 a 14 clusters
    kmeans = KMeans(n_clusters=k, random_state=42, n_init="auto")
    kmeans.fit(X_scaled)
    sse[k] = kmeans.inertia_

# %%
fig = plt.figure(figsize=(8, 4))
ax = fig.add_subplot()

x_values = list(sse.keys())
y_values = list(sse.values())

ax.plot(x_values, y_values, marker="o", label="Inercia (SSE)")
ax.set_xlabel("Número de clusters (k)", fontsize=12)
ax.set_ylabel("Inercia (SSE)", fontsize=12)
ax.legend()
fig.suptitle("Método del Codo (Elbow Method)", fontsize=16)
plt.show()

# %% [markdown]
# ### 7.4. Creacion de pipeline

# %%
# Definir pipeline
pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("kmeans", KMeans(n_clusters=4, random_state=175, n_init="auto"))
])

# Entrenar modelo
pipeline.fit(X)

# Obtener etiquetas de cluster
features_store["cluster"] = pipeline["kmeans"].labels_

# %%
# Distribución por cluster
print(features_store["cluster"].value_counts())
# Out:
# cluster
# 1    6
# 3    2
# 2    1
# 0    1
# Name: count, dtype: int64

# %%
features_store.head(3)
# Out:
#   store_code    mean_sales    std_sales  max_sales  min_sales  mean_revenue  \
# 0      BOS_1  20420.773723  3398.309941      36384       3057  70589.246838
# 1      BOS_2  26329.868613  4466.445893      50154       4189  92207.065652
# 2      BOS_3  22223.832117  4242.063693      38626       3573  80088.320897
#
#     std_revenue  total_sales  total_revenue  cv_revenue  pct_weeks_zero_store  \
# 0  14002.696102      5595292   1.934145e+07    0.198369                   0.0
# 1  16372.548204      7214384   2.526474e+07    0.177563                   0.0
# 2  20657.639427      6089330   2.194420e+07    0.257936                   0.0
#
#    pct_sales_event_store  cluster
# 0               0.291544        3
# 1               0.291037        1
# 2               0.289646        1

# %%
df_store.head()
# Out:
#   store_code      store  region   event  yearweek  n_sales     revenue
# 0      BOS_1  South_End  Boston  Easter    201117    13303  44169.5386
# 1      BOS_1  South_End  Boston  Easter    201215    22651  74461.4573
# 2      BOS_1  South_End  Boston  Easter    201313    21494  71448.4021
# 3      BOS_1  South_End  Boston  Easter    201416    22019  74439.3678
# 4      BOS_1  South_End  Boston  Easter    201514    23324  91501.9022

# %%
# Tomar las columnas categóricas únicas por item
df_cats_store = df_store[["store_code", "store", "region"]].drop_duplicates("store_code")

# Unirlas con tus features agregados
features_store = features_store.merge(df_cats_store, on="store_code", how="left")

# %%
df_store.shape
# Out:
# (2740, 7)

# %%
features_store.head(3)
# Out:
#   store_code    mean_sales    std_sales  max_sales  min_sales  mean_revenue  \
# 0      BOS_1  20420.773723  3398.309941      36384       3057  70589.246838
# 1      BOS_2  26329.868613  4466.445893      50154       4189  92207.065652
# 2      BOS_3  22223.832117  4242.063693      38626       3573  80088.320897
#
#     std_revenue  total_sales  total_revenue  cv_revenue  pct_weeks_zero_store  \
# 0  14002.696102      5595292   1.934145e+07    0.198369                   0.0
# 1  16372.548204      7214384   2.526474e+07    0.177563                   0.0
# 2  20657.639427      6089330   2.194420e+07    0.257936                   0.0
#
#    pct_sales_event_store  cluster      store  region
# 0               0.291544        3  South_End  Boston
# 1               0.291037        1    Roxbury  Boston
# 2               0.289646        1   Back_Bay  Boston

# %%
features_store.to_csv("clustering_store_data.csv", index=False, encoding="utf-8")

# %%
pipeline["kmeans"].labels_.shape
# Out:
# (10,)

# %%
pipeline[:2]
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('kmeans', KMeans(n_clusters=4, random_state=175))])

# %%
features_store["cluster"] = pipeline["kmeans"].labels_

# %%
features_store.head(3)
# Out:
#   store_code    mean_sales    std_sales  max_sales  min_sales  mean_revenue  \
# 0      BOS_1  20420.773723  3398.309941      36384       3057  70589.246838
# 1      BOS_2  26329.868613  4466.445893      50154       4189  92207.065652
# 2      BOS_3  22223.832117  4242.063693      38626       3573  80088.320897
#
#     std_revenue  total_sales  total_revenue  cv_revenue  pct_weeks_zero_store  \
# 0  14002.696102      5595292   1.934145e+07    0.198369                   0.0
# 1  16372.548204      7214384   2.526474e+07    0.177563                   0.0
# 2  20657.639427      6089330   2.194420e+07    0.257936                   0.0
#
#    pct_sales_event_store  cluster      store  region
# 0               0.291544        3  South_End  Boston
# 1               0.291037        1    Roxbury  Boston
# 2               0.289646        1   Back_Bay  Boston

# %% [markdown]
# ### 7.5. Verificacion de clusters por feature

# %%
(
    features_store
    .groupby(["cluster"])
    .describe()
    .T
    .style
    .format('{:.2f}')
    .background_gradient(cmap = 'Blues', axis = 1)
)
# Out:
# <style type="text/css">
# #T_fd612_row0_col0, #T_fd612_row0_col2, #T_fd612_row1_col3, #T_fd612_row2_col1, #T_fd612_row3_col3, #T_fd612_row4_col3, #T_fd612_row5_col3, #T_fd612_row6_col3, #T_fd612_row7_col3, #T_fd612_row8_col0, #T_fd612_row8_col2, #T_fd612_row9_col3, #T_fd612_row10_col3, #T_fd612_row11_col3, #T_fd612_row12_col3, #T_fd612_row13_col3, #T_fd612_row14_col3, #T_fd612_row15_col3, #T_fd612_row16_col0, #T_fd612_row16_col2, #T_fd612_row17_col3, #T_fd612_row18_col1, #T_fd612_row19_col3, #T_fd612_row20_col3, #T_fd612_row21_col3, #T_fd612_row22_col3, #T_fd612_row23_col3, #T_fd612_row24_col0, #T_fd612_row24_col2, #T_fd612_row25_col3, #T_fd612_row26_col1, #T_fd612_row27_col3, #T_fd612_row28_col3, #T_fd612_row29_col3, #T_fd612_row30_col3, #T_fd612_row31_col3, #T_fd612_row32_col0, #T_fd612_row32_col2, #T_fd612_row33_col3, #T_fd612_row34_col3, #T_fd612_row35_col3, #T_fd612_row36_col3, #T_fd612_row37_col3, #T_fd612_row38_col3, #T_fd612_row39_col3, #T_fd612_row40_col0, #T_fd612_row40_col2, #T_fd612_row41_col3, #T_fd612_row42_col3, #T_fd612_row43_col3, #T_fd612_row44_col3, #T_fd612_row45_col3, #T_fd612_row46_col3, #T_fd612_row47_col3, #T_fd612_row48_col0, #T_fd612_row48_col2, #T_fd612_row49_col3, #T_fd612_row50_col1, #T_fd612_row51_col3, #T_fd612_row52_col3, #T_fd612_row53_col3, #T_fd612_row54_col3, #T_fd612_row55_col3, #T_fd612_row56_col0, #T_fd612_row56_col2, #T_fd612_row57_col3, #T_fd612_row58_col3, #T_fd612_row59_col3, #T_fd612_row60_col3, #T_fd612_row61_col3, #T_fd612_row62_col3, #T_fd612_row63_col3, #T_fd612_row64_col0, #T_fd612_row64_col2, #T_fd612_row65_col2, #T_fd612_row66_col3, #T_fd612_row67_col1, #T_fd612_row68_col1, #T_fd612_row69_col2, #T_fd612_row70_col2, #T_fd612_row71_col2, #T_fd612_row72_col0, #T_fd612_row72_col2, #T_fd612_row73_col0, #T_fd612_row73_col1, #T_fd612_row73_col2, #T_fd612_row73_col3, #T_fd612_row74_col0, #T_fd612_row74_col1, #T_fd612_row74_col2, #T_fd612_row74_col3, #T_fd612_row75_col0, #T_fd612_row75_col1, #T_fd612_row75_col2, #T_fd612_row75_col3, #T_fd612_row76_col0, #T_fd612_row76_col1, #T_fd612_row76_col2, #T_fd612_row76_col3, #T_fd612_row77_col0, #T_fd612_row77_col1, #T_fd612_row77_col2, #T_fd612_row77_col3, #T_fd612_row78_col0, #T_fd612_row78_col1, #T_fd612_row78_col2, #T_fd612_row78_col3, #T_fd612_row79_col0, #T_fd612_row79_col1, #T_fd612_row79_col2, #T_fd612_row79_col3, #T_fd612_row80_col0, #T_fd612_row80_col2, #T_fd612_row81_col2, #T_fd612_row82_col3, #T_fd612_row83_col2, #T_fd612_row83_col3, #T_fd612_row84_col2, #T_fd612_row85_col2, #T_fd612_row86_col2, #T_fd612_row87_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fd612_row0_col1, #T_fd612_row1_col2, #T_fd612_row2_col3, #T_fd612_row3_col2, #T_fd612_row4_col2, #T_fd612_row5_col2, #T_fd612_row6_col2, #T_fd612_row7_col2, #T_fd612_row8_col1, #T_fd612_row9_col0, #T_fd612_row10_col1, #T_fd612_row11_col0, #T_fd612_row12_col0, #T_fd612_row13_col0, #T_fd612_row14_col0, #T_fd612_row15_col0, #T_fd612_row16_col1, #T_fd612_row17_col2, #T_fd612_row18_col3, #T_fd612_row19_col2, #T_fd612_row20_col2, #T_fd612_row21_col2, #T_fd612_row22_col2, #T_fd612_row23_col2, #T_fd612_row24_col1, #T_fd612_row25_col2, #T_fd612_row26_col3, #T_fd612_row27_col2, #T_fd612_row28_col2, #T_fd612_row29_col2, #T_fd612_row30_col2, #T_fd612_row31_col2, #T_fd612_row32_col1, #T_fd612_row33_col2, #T_fd612_row34_col1, #T_fd612_row35_col2, #T_fd612_row36_col2, #T_fd612_row37_col2, #T_fd612_row38_col2, #T_fd612_row39_col2, #T_fd612_row40_col1, #T_fd612_row41_col0, #T_fd612_row42_col1, #T_fd612_row43_col0, #T_fd612_row44_col0, #T_fd612_row45_col0, #T_fd612_row46_col0, #T_fd612_row47_col0, #T_fd612_row48_col1, #T_fd612_row49_col2, #T_fd612_row50_col3, #T_fd612_row51_col2, #T_fd612_row52_col2, #T_fd612_row53_col2, #T_fd612_row54_col2, #T_fd612_row55_col2, #T_fd612_row56_col1, #T_fd612_row57_col2, #T_fd612_row58_col1, #T_fd612_row59_col2, #T_fd612_row60_col2, #T_fd612_row61_col2, #T_fd612_row62_col2, #T_fd612_row63_col2, #T_fd612_row64_col1, #T_fd612_row65_col0, #T_fd612_row66_col1, #T_fd612_row67_col0, #T_fd612_row68_col0, #T_fd612_row69_col0, #T_fd612_row70_col0, #T_fd612_row71_col0, #T_fd612_row72_col1, #T_fd612_row80_col1, #T_fd612_row81_col0, #T_fd612_row82_col1, #T_fd612_row83_col0, #T_fd612_row84_col0, #T_fd612_row85_col0, #T_fd612_row86_col1, #T_fd612_row87_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fd612_row0_col3, #T_fd612_row8_col3, #T_fd612_row16_col3, #T_fd612_row24_col3, #T_fd612_row32_col3, #T_fd612_row33_col0, #T_fd612_row37_col0, #T_fd612_row40_col3, #T_fd612_row48_col3, #T_fd612_row56_col3, #T_fd612_row57_col0, #T_fd612_row61_col0, #T_fd612_row64_col3, #T_fd612_row72_col3, #T_fd612_row80_col3 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_fd612_row1_col0, #T_fd612_row5_col0, #T_fd612_row49_col0, #T_fd612_row53_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_fd612_row1_col1, #T_fd612_row33_col1, #T_fd612_row49_col1, #T_fd612_row57_col1 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_fd612_row2_col0, #T_fd612_row2_col2, #T_fd612_row10_col0, #T_fd612_row10_col2, #T_fd612_row18_col0, #T_fd612_row18_col2, #T_fd612_row26_col0, #T_fd612_row26_col2, #T_fd612_row34_col0, #T_fd612_row34_col2, #T_fd612_row42_col0, #T_fd612_row42_col2, #T_fd612_row50_col0, #T_fd612_row50_col2, #T_fd612_row58_col0, #T_fd612_row58_col2, #T_fd612_row66_col0, #T_fd612_row66_col2, #T_fd612_row82_col0, #T_fd612_row82_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_fd612_row3_col0, #T_fd612_row51_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_fd612_row3_col1, #T_fd612_row51_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_fd612_row4_col0, #T_fd612_row52_col0 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_fd612_row4_col1, #T_fd612_row52_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_fd612_row5_col1, #T_fd612_row6_col0, #T_fd612_row53_col1, #T_fd612_row54_col0 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_fd612_row6_col1, #T_fd612_row9_col1, #T_fd612_row21_col1, #T_fd612_row54_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_fd612_row7_col0, #T_fd612_row55_col0 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_fd612_row7_col1, #T_fd612_row55_col1 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_fd612_row9_col2, #T_fd612_row13_col2 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_fd612_row11_col1, #T_fd612_row44_col1 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_fd612_row11_col2 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_fd612_row12_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_fd612_row12_col2 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_fd612_row13_col1 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_fd612_row14_col1 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_fd612_row14_col2 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_fd612_row15_col1 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_fd612_row15_col2 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_fd612_row17_col0, #T_fd612_row21_col0 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_fd612_row17_col1, #T_fd612_row29_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_fd612_row19_col0 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_fd612_row19_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_fd612_row20_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_fd612_row20_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_fd612_row22_col0 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_fd612_row22_col1 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_fd612_row23_col0 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_fd612_row23_col1, #T_fd612_row25_col0, #T_fd612_row29_col0 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_fd612_row25_col1 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_fd612_row27_col0 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_fd612_row27_col1, #T_fd612_row35_col0, #T_fd612_row59_col0 {

# %% [markdown]
# ## 8. Ficha de tiendas

# %%
ficha_store = pd.DataFrame()

# %%
for i, col in enumerate(["mean_sales", "total_sales", "cv_revenue", "mean_revenue"]):
    resumen_data = features_store[["cluster", col]].groupby("cluster").describe().T[1:]
    ficha_store = pd.concat([ficha_store, resumen_data])

# %%
ficha_store
# Out:
# cluster                       0             1             2             3
# mean_sales   mean  2.388326e+04  2.327509e+04  4.083277e+04  1.769885e+04
#              std            NaN  3.469340e+03           NaN  3.849386e+03
#              min   2.388326e+04  1.879220e+04  4.083277e+04  1.497692e+04
#              25%   2.388326e+04  2.111839e+04  4.083277e+04  1.633788e+04
#              50%   2.388326e+04  2.284145e+04  4.083277e+04  1.769885e+04
#              75%   2.388326e+04  2.561217e+04  4.083277e+04  1.905981e+04
#              max   2.388326e+04  2.809568e+04  4.083277e+04  2.042077e+04
# total_sales  mean  6.544012e+06  6.377375e+06  1.118818e+07  4.849484e+06
#              std            NaN  9.505992e+05           NaN  1.054732e+06
#              min   6.544012e+06  5.149062e+06  1.118818e+07  4.103676e+06
#              25%   6.544012e+06  5.786439e+06  1.118818e+07  4.476580e+06
#              50%   6.544012e+06  6.258556e+06  1.118818e+07  4.849484e+06
#              75%   6.544012e+06  7.017734e+06  1.118818e+07  5.222388e+06
#              max   6.544012e+06  7.698216e+06  1.118818e+07  5.595292e+06
# cv_revenue   mean  3.944235e-01  2.373411e-01  2.044476e-01  2.123239e-01
#              std            NaN  5.814019e-02           NaN  1.973572e-02
#              min   3.944235e-01  1.775628e-01  2.044476e-01  1.983687e-01
#              25%   3.944235e-01  2.017050e-01  2.044476e-01  2.053463e-01
#              50%   3.944235e-01  2.242673e-01  2.044476e-01  2.123239e-01
#              75%   3.944235e-01  2.537093e-01  2.044476e-01  2.193016e-01
#              max   3.944235e-01  3.402418e-01  2.044476e-01  2.262792e-01
# mean_revenue mean  7.903830e+04  8.238140e+04  1.441488e+05  6.275125e+04
#              std            NaN  1.238325e+04           NaN  1.108460e+04
#              min   7.903830e+04  6.654501e+04  1.441488e+05  5.491325e+04
#              25%   7.903830e+04  7.642509e+04  1.441488e+05  5.883225e+04
#              50%   7.903830e+04  7.929093e+04  1.441488e+05  6.275125e+04
#              75%   7.903830e+04  8.917738e+04  1.441488e+05  6.667025e+04
#              max   7.903830e+04  1.012188e+05  1.441488e+05  7.058925e+04

# %%
# generamos nuestro multiindex
out_index_store = [
    "Rendimiento base",
    "Volumen total",
    "Estabilidad",
    "Rentabilidad"
]

inner_index_store = [
    "mean_sales", "total_sales", "cv_revenue", "mean_revenue"
]

estadisticos_store = ["Media", "Desviación", "Mínimo", "Perc. 25", "Perc. 50", "Perc. 75", "Máximo"]

new_multi_index_store = []

for oi, ii, in zip(out_index_store, inner_index_store):
    for es in estadisticos_store:
        new_multi_index_store.append((oi, ii, es))

# %%
# def generate_multiindex(list_of_tuples, names):
#     return pd.MultiIndex.from_tuples(list_of_tuples, names = names)

# %%
names = ["Grupo Indicadores", "Indicador", "Estadístico"]
index_ficha_store = generate_multiindex(new_multi_index_store, names)
ficha_store.set_index(index_ficha_store, inplace = True)

# %%
tamaño_clusters_store = features_store.groupby("cluster").size().to_frame().T
tamaño_clusters_store.set_index(generate_multiindex([("General", "Clúster", "Tamaño")] , names), inplace = True)

# %%
ficha_store = pd.concat([tamaño_clusters_store, ficha_store])

# %%
ficha_store
# Out:
# cluster                                                0             1  \
# Grupo Indicadores Indicador    Estadístico
# General           Clúster      Tamaño       1.000000e+00  6.000000e+00
# Rendimiento base  mean_sales   Media        2.388326e+04  2.327509e+04
#                                Desviación            NaN  3.469340e+03
#                                Mínimo       2.388326e+04  1.879220e+04
#                                Perc. 25     2.388326e+04  2.111839e+04
#                                Perc. 50     2.388326e+04  2.284145e+04
#                                Perc. 75     2.388326e+04  2.561217e+04
#                                Máximo       2.388326e+04  2.809568e+04
# Volumen total     total_sales  Media        6.544012e+06  6.377375e+06
#                                Desviación            NaN  9.505992e+05
#                                Mínimo       6.544012e+06  5.149062e+06
#                                Perc. 25     6.544012e+06  5.786439e+06
#                                Perc. 50     6.544012e+06  6.258556e+06
#                                Perc. 75     6.544012e+06  7.017734e+06
#                                Máximo       6.544012e+06  7.698216e+06
# Estabilidad       cv_revenue   Media        3.944235e-01  2.373411e-01
#                                Desviación            NaN  5.814019e-02
#                                Mínimo       3.944235e-01  1.775628e-01
#                                Perc. 25     3.944235e-01  2.017050e-01
#                                Perc. 50     3.944235e-01  2.242673e-01
#                                Perc. 75     3.944235e-01  2.537093e-01
#                                Máximo       3.944235e-01  3.402418e-01
# Rentabilidad      mean_revenue Media        7.903830e+04  8.238140e+04
#                                Desviación            NaN  1.238325e+04
#                                Mínimo       7.903830e+04  6.654501e+04
#                                Perc. 25     7.903830e+04  7.642509e+04
#                                Perc. 50     7.903830e+04  7.929093e+04
#                                Perc. 75     7.903830e+04  8.917738e+04
#                                Máximo       7.903830e+04  1.012188e+05
#
# cluster                                                2             3
# Grupo Indicadores Indicador    Estadístico
# General           Clúster      Tamaño       1.000000e+00  2.000000e+00
# Rendimiento base  mean_sales   Media        4.083277e+04  1.769885e+04
#                                Desviación            NaN  3.849386e+03
#                                Mínimo       4.083277e+04  1.497692e+04
#                                Perc. 25     4.083277e+04  1.633788e+04
#                                Perc. 50     4.083277e+04  1.769885e+04
#                                Perc. 75     4.083277e+04  1.905981e+04
#                                Máximo       4.083277e+04  2.042077e+04
# Volumen total     total_sales  Media        1.118818e+07  4.849484e+06
#                                Desviación            NaN  1.054732e+06
#                                Mínimo       1.118818e+07  4.103676e+06
#                                Perc. 25     1.118818e+07  4.476580e+06
#                                Perc. 50     1.118818e+07  4.849484e+06
#                                Perc. 75     1.118818e+07  5.222388e+06
#                                Máximo       1.118818e+07  5.595292e+06
# Estabilidad       cv_revenue   Media        2.044476e-01  2.123239e-01
#                                Desviación            NaN  1.973572e-02
#                                Mínimo       2.044476e-01  1.983687e-01
#                                Perc. 25     2.044476e-01  2.053463e-01
#                                Perc. 50     2.044476e-01  2.123239e-01
#                                Perc. 75     2.044476e-01  2.193016e-01
#                                Máximo       2.044476e-01  2.262792e-01
# Rentabilidad      mean_revenue Media        1.441488e+05  6.275125e+04
#                                Desviación            NaN  1.108460e+04
#                                Mínimo       1.441488e+05  5.491325e+04
#                                Perc. 25     1.441488e+05  5.883225e+04
#                                Perc. 50     1.441488e+05  6.275125e+04
#                                Perc. 75     1.441488e+05  6.667025e+04
#                                Máximo       1.441488e+05  7.058925e+04

# %%
float_format = '{:.2f}'

# %%
(
    ficha_store
    .rename(columns = {
        0 : "Tiendas irregulares",
        1 : "Tiendas estables",
        2 : "Tiendas premium",
        3 : "Tiendas bajo rendimiento"
    })
    .style
    .format(float_format)
    .background_gradient(cmap = 'Blues', axis = 1)
)
# Out:
# <style type="text/css">
# #T_dc5e5_row0_col0, #T_dc5e5_row0_col2, #T_dc5e5_row1_col3, #T_dc5e5_row2_col1, #T_dc5e5_row3_col3, #T_dc5e5_row4_col3, #T_dc5e5_row5_col3, #T_dc5e5_row6_col3, #T_dc5e5_row7_col3, #T_dc5e5_row8_col3, #T_dc5e5_row9_col1, #T_dc5e5_row10_col3, #T_dc5e5_row11_col3, #T_dc5e5_row12_col3, #T_dc5e5_row13_col3, #T_dc5e5_row14_col3, #T_dc5e5_row15_col2, #T_dc5e5_row16_col3, #T_dc5e5_row17_col1, #T_dc5e5_row18_col1, #T_dc5e5_row19_col2, #T_dc5e5_row20_col2, #T_dc5e5_row21_col2, #T_dc5e5_row22_col3, #T_dc5e5_row23_col3, #T_dc5e5_row24_col3, #T_dc5e5_row25_col3, #T_dc5e5_row26_col3, #T_dc5e5_row27_col3, #T_dc5e5_row28_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_dc5e5_row0_col1, #T_dc5e5_row1_col2, #T_dc5e5_row2_col3, #T_dc5e5_row3_col2, #T_dc5e5_row4_col2, #T_dc5e5_row5_col2, #T_dc5e5_row6_col2, #T_dc5e5_row7_col2, #T_dc5e5_row8_col2, #T_dc5e5_row9_col3, #T_dc5e5_row10_col2, #T_dc5e5_row11_col2, #T_dc5e5_row12_col2, #T_dc5e5_row13_col2, #T_dc5e5_row14_col2, #T_dc5e5_row15_col0, #T_dc5e5_row16_col1, #T_dc5e5_row17_col0, #T_dc5e5_row18_col0, #T_dc5e5_row19_col0, #T_dc5e5_row20_col0, #T_dc5e5_row21_col0, #T_dc5e5_row22_col2, #T_dc5e5_row23_col1, #T_dc5e5_row24_col2, #T_dc5e5_row25_col2, #T_dc5e5_row26_col2, #T_dc5e5_row27_col2, #T_dc5e5_row28_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_dc5e5_row0_col3, #T_dc5e5_row22_col0, #T_dc5e5_row26_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_dc5e5_row1_col0, #T_dc5e5_row5_col0, #T_dc5e5_row8_col0, #T_dc5e5_row12_col0 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_dc5e5_row1_col1, #T_dc5e5_row8_col1, #T_dc5e5_row22_col1 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_dc5e5_row2_col0, #T_dc5e5_row2_col2, #T_dc5e5_row9_col0, #T_dc5e5_row9_col2, #T_dc5e5_row16_col0, #T_dc5e5_row16_col2, #T_dc5e5_row23_col0, #T_dc5e5_row23_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_dc5e5_row3_col0, #T_dc5e5_row10_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_dc5e5_row3_col1, #T_dc5e5_row10_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_dc5e5_row4_col0, #T_dc5e5_row11_col0 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_dc5e5_row4_col1, #T_dc5e5_row11_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_dc5e5_row5_col1, #T_dc5e5_row6_col0, #T_dc5e5_row12_col1, #T_dc5e5_row13_col0 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_dc5e5_row6_col1, #T_dc5e5_row13_col1 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_dc5e5_row7_col0, #T_dc5e5_row14_col0 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_dc5e5_row7_col1, #T_dc5e5_row14_col1 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_dc5e5_row15_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_dc5e5_row15_col3, #T_dc5e5_row19_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_dc5e5_row17_col2 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_dc5e5_row17_col3 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_dc5e5_row18_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_dc5e5_row18_col3 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_dc5e5_row19_col1 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_dc5e5_row20_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_dc5e5_row20_col3 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_dc5e5_row21_col1 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_dc5e5_row21_col3, #T_dc5e5_row28_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_dc5e5_row24_col0 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_dc5e5_row24_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_dc5e5_row25_col0 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_dc5e5_row25_col1, #T_dc5e5_row26_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_dc5e5_row27_col0 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_dc5e5_row27_col1 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_dc5e5_row28_col1 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# </style>
# <table id="T_dc5e5">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >cluster</th>
#       <th id="T_dc5e5_level0_col0" class="col_heading level0 col0" >Tiendas irregulares</th>
#       <th id="T_dc5e5_level0_col1" class="col_heading level0 col1" >Tiendas estables</th>
#       <th id="T_dc5e5_level0_col2" class="col_heading level0 col2" >Tiendas premium</th>
#       <th id="T_dc5e5_level0_col3" class="col_heading level0 col3" >Tiendas bajo rendimiento</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Grupo Indicadores</th>
#       <th class="index_name level1" >Indicador</th>
#       <th class="index_name level2" >Estadístico</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc5e5_level0_row0" class="row_heading level0 row0" >General</th>
#       <th id="T_dc5e5_level1_row0" class="row_heading level1 row0" >Clúster</th>
#       <th id="T_dc5e5_level2_row0" class="row_heading level2 row0" >Tamaño</th>
#       <td id="T_dc5e5_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_dc5e5_row0_col1" class="data row0 col1" >6.00</td>
#       <td id="T_dc5e5_row0_col2" class="data row0 col2" >1.00</td>
#       <td id="T_dc5e5_row0_col3" class="data row0 col3" >2.00</td>
#     </tr>
#     <tr>
#       <th id="T_dc5e5_level0_row1" class="row_heading level0 row1" rowspan="7">Rendimiento base</th>
#       <th id="T_dc5e5_level1_row1" class="row_heading level1 row1" rowspan="7">mean_sales</th>
#       <th id="T_dc5e5_level2_row1" class="row_heading level2 row1" >Media</th>
#       <td id="T_dc5e5_row1_col0" class="data row1 col0" >23883.26</td>
#       <td id="T_dc5e5_row1_col1" class="data row1 col1" >23275.09</td>
#       <td id="T_dc5e5_row1_col2" class="data row1 col2" >40832.77</td>
#       <td id="T_dc5e5_row1_col3" class="data row1 col3" >17698.85</td>
#     </tr>
#     <tr>
#       <th id="T_dc5e5_level2_row2" class="row_heading level2 row2" >Desviación</th>
#       <td id="T_dc5e5_row2_col0" class="data row2 col0" >nan</td>
#       <td id="T_dc5e5_row2_col1" class="data row2 col1" >3469.34</td>
#       <td id="T_dc5e5_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_dc5e5_row2_col3" class="data row2 col3" >3849.39</td>
#     </tr>
#     <tr>
#       <th id="T_dc5e5_level2_row3" class="row_heading level2 row3" >Mínimo</th>
#       <td id="T_dc5e5_row3_col0" class="data row3 col0" >23883.26</td>
#       <td id="T_dc5e5_row3_col1" class="data row3 col1" >18792.20</td>
#       <td id="T_dc5e5_row3_col2" class="data row3 col2" >40832.77</td>
#       <td id="T_dc5e5_row3_col3" class="data row3 col3" >14976.92</td>
#     </tr>
#     <tr>
#       <th id="T_dc5e5_level2_row4" class="row_heading level2 row4" >Perc. 25</th>
#       <td id="T_dc5e5_row4_col0" class="data row4 col0" >23883.26</td>
#       <td id="T_dc5e5_row4_col1" class="data row4 col1" >21118.39</td>
#       <td id="T_dc5e5_row4_col2" class="data row4 col2" >40832.77</td>
#       <td id="T_dc5e5_row4_col3" class="data row4 col3" >16337.88</td>
#     </tr>
#     <tr>
#       <th id="T_dc5e5_level2_row5" class="row_heading level2 row5" >Perc. 50</th>
#       <td id="T_dc5e5_row5_col0" class="data row5 col0" >23883.26</td>
#       <td id="T_dc5e5_row5_col1" class="data row5 col1" >22841.45</td>
#       <td id="T_dc5e5_row5_col2" class="data row5 col2" >40832.77</td>
#       <td id="T_dc5e5_row5_col3" class="data row5 col3" >17698.85</td>
#     </tr>
#     <tr>
#       <th id="T_dc5e5_level2_row6" class="row_heading level2 row6" >Perc. 75</th>
#       <td id="T_dc5e5_row6_col0" class="data row6 col0" >23883.26</td>
#       <td id="T_dc5e5_row6_col1" class="data row6 col1" >25612.17</td>
#       <td id="T_dc5e5_row6_col2" class="data row6 col2" >40832.77</td>
#       <td id="T_dc5e5_row6_col3" class="data row6 col3" >19059.81</td>
#     </tr>
#     <tr>
#       <th id="T_dc5e5_le

# %% [markdown]
# ## 9. Creacion fichero para forecasting

# %%
df.head(3)
# Out:
#                                     item    category    department      store  \
# id
# ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End
# ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End
# ACCESORIES_1_001_BOS_1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End
#
#                        store_code  region  yearweek  n_sales  revenue  \
# id
# ACCESORIES_1_001_BOS_1      BOS_1  Boston    201105        0      0.0
# ACCESORIES_1_001_BOS_1      BOS_1  Boston    201106        0      0.0
# ACCESORIES_1_001_BOS_1      BOS_1  Boston    201107        0      0.0
#
#                         avg_sell_price            event
# id
# ACCESORIES_1_001_BOS_1         12.7414    Without event
# ACCESORIES_1_001_BOS_1         12.7414        SuperBowl
# ACCESORIES_1_001_BOS_1         12.7414  Valentine's Day

# %%
features_store.head(3)
# Out:
#   store_code    mean_sales    std_sales  max_sales  min_sales  mean_revenue  \
# 0      BOS_1  20420.773723  3398.309941      36384       3057  70589.246838
# 1      BOS_2  26329.868613  4466.445893      50154       4189  92207.065652
# 2      BOS_3  22223.832117  4242.063693      38626       3573  80088.320897
#
#     std_revenue  total_sales  total_revenue  cv_revenue  pct_weeks_zero_store  \
# 0  14002.696102      5595292   1.934145e+07    0.198369                   0.0
# 1  16372.548204      7214384   2.526474e+07    0.177563                   0.0
# 2  20657.639427      6089330   2.194420e+07    0.257936                   0.0
#
#    pct_sales_event_store  cluster      store  region
# 0               0.291544        3  South_End  Boston
# 1               0.291037        1    Roxbury  Boston
# 2               0.289646        1   Back_Bay  Boston

# %%
features_item.head(3)
# Out:
#                item  mean_sales  std_sales  max_sales  min_sales  \
# 0  ACCESORIES_1_001   14.937956  15.317871         58          0
# 1  ACCESORIES_1_002   18.463504  10.965837        102          0
# 2  ACCESORIES_1_003    5.237226   7.646872         37          0
#
#    mean_revenue  std_revenue  total_sales  total_revenue  avg_price  \
# 0    164.371399   168.393424         4093     45037.7634  11.467561
# 1     97.474729    57.902918         5059     26708.0758   5.276746
# 2     20.643590    30.192925         1435      5656.3437   3.947629
#
#    cv_revenue  pct_weeks_zero  pct_sales_event  cluster    category  \
# 0    1.024469        0.467153         0.298803        0  ACCESORIES
# 1    0.594030        0.062044         0.320617        3  ACCESORIES
# 2    1.462581        0.591241         0.340070        0  ACCESORIES
#
#      department
# 0  ACCESORIES_1
# 1  ACCESORIES_1
# 2  ACCESORIES_1

# %%
cluster_store = features_store[["store_code", "cluster"]].drop_duplicates()
cluster_item = features_item[["item", "cluster"]].drop_duplicates()

# %%
cluster_store
# Out:
#   store_code  cluster
# 0      BOS_1        3
# 1      BOS_2        1
# 2      BOS_3        1
# 3      NYC_1        1
# 4      NYC_2        1
# 5      NYC_3        2
# 6      NYC_4        3
# 7      PHI_1        1
# 8      PHI_2        0
# 9      PHI_3        1

# %%
cluster_item
# Out:
#                    item  cluster
# 0      ACCESORIES_1_001        0
# 1      ACCESORIES_1_002        3
# 2      ACCESORIES_1_003        0
# 3      ACCESORIES_1_004        3
# 4      ACCESORIES_1_005        3
# ...                 ...      ...
# 3044  SUPERMARKET_3_823        3
# 3045  SUPERMARKET_3_824        3
# 3046  SUPERMARKET_3_825        3
# 3047  SUPERMARKET_3_826        0
# 3048  SUPERMARKET_3_827        0
#
# [3049 rows x 2 columns]

# %%
df.shape
# Out:
# (8354260, 11)

# %%
df = (
    df
    .merge(cluster_store, on="store_code", how="left")
    .rename(columns={'cluster': 'cluster_store'})
    .merge(cluster_item, on="item", how="left")
    .rename(columns={'cluster': 'cluster_item'})
)

# %%
df.shape
# Out:
# (8354260, 13)

# %%
df.head(3)
# Out:
#                item    category    department      store store_code  region  \
# 0  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End      BOS_1  Boston
# 1  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End      BOS_1  Boston
# 2  ACCESORIES_1_001  ACCESORIES  ACCESORIES_1  South_End      BOS_1  Boston
#
#    yearweek  n_sales  revenue  avg_sell_price            event  cluster_store  \
# 0    201105        0      0.0         12.7414    Without event              3
# 1    201106        0      0.0         12.7414        SuperBowl              3
# 2    201107        0      0.0         12.7414  Valentine's Day              3
#
#    cluster_item
# 0             0
# 1             0
# 2             0

# %%
df.to_parquet('df_forecasting.parquet', engine='pyarrow', index=False, compression='snappy')
